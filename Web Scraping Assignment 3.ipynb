# %%
# Imports required libraries

import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Q1: Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# specifying the url of the webpage to be scraped and to maximize the window
url = 'https://www.amazon.in/'
driver.get(url)
driver.maximize_window()

# %%
# Entering the product that we want to search
user_input = input('Enter the product that we want to search : ')
# Out:
# Enter the product that we want to search : Guitar

# %%
#  web element for user input
search = driver.find_element_by_id("twotabsearchtextbox")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="697b4f6eb60e6392a47b44c45a521e4e", element="053d91ab-43de-44bd-8042-e06096bc8eb5")>

# %%
# Sending the user input to search bar
search.send_keys(user_input)

# %%
# Locating the search button using xpath
searchbtn = driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']/span/input")
# Clicking on search button
searchbtn.click()

# %% [markdown]
# Q2: In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical hasless than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. ofRatings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"and “Product URL”. In case, if any of the details are missing for any of the product then replace it by "-".

# %%
# Fetching URLs to open the pages
urls = []    # Empty list
for i in range(0,3):   # for loop to scrape 3 pages
    page_url = driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']/a")
    for i in page_url:
        urls.append(i.get_attribute("href"))
    next_btn = driver.find_elements_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")
time.sleep(3)

# %%
len(urls)
# Out:
# 180

# %%
BrandName = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    try:
        brand = driver.find_element_by_xpath("//a[@id='bylineInfo']")
        BrandName.append(brand.text)
    except NoSuchElementException:
        BrandName.append('-')

# %%
len(BrandName)
# Out:
# 180

# %%
time.sleep(2)
# Extracting Name of the Product
Product_Name = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        name = driver.find_element_by_xpath("//span[@id='productTitle']")
        Product_Name.append(name.text)
    except NoSuchElementException:
        Product_Name.append('-')

# %%
len(Product_Name)
# Out:
# 180

# %%
Product_Name
# Out:
# ['Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Festra 38C, 38 Inch Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks (Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern 38C Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gigbag, Picks, String Set, Strap & Cloth - Black',
#  'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar with Bag, Strings, Pick and Strap (Natural, 6 Strings)',
#  'Photron Acoustic Guitar, 38 Inch Cutaway, PH38C/BK with Picks Only, Black (Without Bag, Strap and Extra Strings)',
#  'Yamaha Classical Guitar C40//02',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Juarez JRZ-ST01 6-String Electric Guitar, Right Handed, Full Black, with Case/Bag and Picks',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Red',
#  'Juarez JRZ-ST01, 6 Strings Electric Guitar, Right Handed with Bag/Case, 2 x Picks (3TS Sunburst)',
#  'Intern INT-38C Sunburst Acoustic Guitar kit with carry bag & picks',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  "HOMME STORE 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children, multi-coloured",
#  'Vault EA40 41 inch Premium Solid Spruce-Top Cutaway Acoustic Guitar',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'HOMME STORE 4 String Guitar Kids Brown Plastic 4 String Acoustic Guitar for Kids Musical Instrument Learning Educational Small Toy for Boys & Girls (Wooden Guitar) (1)',
#  'Medellin 38" Acoustic Guitar Black Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand.',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
#  'Intern INT-38C Acoustic Guitar Kit (Sunburst) with Carry bag, Picks, Strings set and Guitar Strap, Small',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, 3TS Sunburst',
#  'Intern INT-38C-BK-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Black, 6 Strings)',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand.',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38CPG with Bag, Strings, Pick and Strap, Black',
#  'Kadence Guitar Acoustica Series A05, Electric Acoustic Guitar, Zebra Wood with Pickup, Inbuilt tuner and Bag (Zebra Wood, Electro Acoustic)',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Sunburst finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Yamaha FSX80C Semi Acoustic Cutaway Guitar with Bag (Natural)',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'Kadence Acoustica 34” Acoustic Guitar A03 with bag',
#  'Medellin 38" Acoustic Guitar Brown Carbon Fiber Body with FREE Online LEARNING COURSE Durable Matt finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'JUAREZ Arpéggio 104.14 cm (41 Inch) Semi-Acoustic Guitar Kit, Thin Line Body, Spruce Top, with 4 Band EQ, Natural',
#  'JUAREZ Acoustic Guitar 3xE 1st String & 2 Pick Set JRGSE32',
#  'Neowood AT-01A-Guitar Tuner-Black Automatic Digital Tuner (Chromatic: Yes, Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Red',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'Yamaha PACIFICA012 Electric Guitar, Red Metallic',
#  'Revel 38 Inches Cutaway Design Acoustic Guitar with Carry bag and Plectrums. Great tone and Beginner/Learners standard size configuration for all age groups (Natural)',
#  'Yamaha FX280 Semi acoustic Dreadnought Guitar with Bag (Natural)',
#  'Yamaha FS100C Acoustic Guitar, Black',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner)',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Pink finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Yamaha F310 Acoustic Guitar, Tobacco Brown Sunburst',
#  'Ibanez GRG121DX Electric Guitar',
#  'Kadence Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set of Strings, Strap, Picks and Bag (Black EQ, Electric Acoustic)',
#  'Juarez ST38 Electric Guitar Kit/Set, Right Handed, Blue, With Case/Bag & Picks',
#  'Intern 38C Acoustic Steel-string Guitar Premium White Cutaway Design with carry bag, strings, guitar strap and plectrums (INT-38C-WH)',
#  'RockJam RJEG02-SK-BB Electric Guitar Starter Kit (Blue Burst)',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Brown)',
#  'Cort AD810 Dreadnought Acoustic Guitar with Gig Bag,Tuner,Picks and Strap (Natural Bundle)',
#  'Kaps ST - 1ACM, 6-Strings, Acoustic Guitar , Right-Handed, Wine Red, With Guitar Cover/Bag',
#  'SHARE BY Blueberry R-40- Trussrod Acoustic Guitar Kit with Bag, Strap, One Pack Strings and Picks (Natural)',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Festra 38C, 38 Inch Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks (Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern 38C Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gigbag, Picks, String Set, Strap & Cloth - Black',
#  'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar with Bag, Strings, Pick and Strap (Natural, 6 Strings)',
#  'Photron Acoustic Guitar, 38 Inch Cutaway, PH38C/BK with Picks Only, Black (Without Bag, Strap and Extra Strings)',
#  'Yamaha Classical Guitar C40//02',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Juarez JRZ-ST01 6-String Electric Guitar, Right Handed, Full Black, with Case/Bag and Picks',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Red',
#  'Juarez JRZ-ST01, 6 Strings Electric Guitar, Right Handed with Bag/Case, 2 x Picks (3TS Sunburst)',
#  'Intern INT-38C Sunburst Acoustic Guitar kit with carry bag & picks',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  "HOMME STORE 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children, multi-coloured",
#  'Vault EA40 41 inch Premium Solid Spruce-Top Cutaway Acoustic Guitar',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'HOMME STORE 4 String Guitar Kids Brown Plastic 4 String Acoustic Guitar for Kids Musical Instrument Learning Educational Small Toy for Boys & Girls (Wooden Guitar) (1)',
#  '-',
#  '-',
#  '-',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, 3TS Sunburst',
#  '-',
#  '-',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38CPG with Bag, Strings, Pick and Strap, Black',
#  '-',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Sunburst finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Yamaha FSX80C Semi Acoustic Cutaway Guitar with Bag (Natural)',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'Kadence Acoustica 34” Acoustic Guitar A03 with bag',
#  'Medellin 38" Acoustic Guitar Brown Carbon Fiber Body with FREE Online LEARNING COURSE Durable Matt finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'JUAREZ Arpéggio 104.14 cm (41 Inch) Semi-Acoustic Guitar Kit, Thin Line Body, Spruce Top, with 4 Band EQ, Natural',
#  'JUAREZ Acoustic Guitar 3xE 1st String & 2 Pick Set JRGSE32',
#  'Neowood AT-01A-Guitar Tuner-Black Automatic Digital Tuner (Chromatic: Yes, Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Red',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'Yamaha PACIFICA012 Electric Guitar, Red Metallic',
#  'Revel 38 Inches Cutaway Design Acoustic Guitar with Carry bag and Plectrums. Great tone and Beginner/Learners standard size configuration for all age groups (Natural)',
#  'Yamaha FX280 Semi acoustic Dreadnought Guitar with Bag (Natural)',
#  'Yamaha FS100C Acoustic Guitar, Black',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner)',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Pink finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Yamaha F310 Acoustic Guitar, Tobacco Brown Sunburst',
#  'Ibanez GRG121DX Electric Guitar',
#  'Kadence Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set of Strings, Strap, Picks and Bag (Black EQ, Electric Acoustic)',
#  'Juarez ST38 Electric Guitar Kit/Set, Right Handed, Blue, With Case/Bag & Picks',
#  'Intern 38C Acoustic Steel-string Guitar Premium White Cutaway Design with carry bag, strings, guitar strap and plectrums (INT-38C-WH)',
#  'RockJam RJEG02-SK-BB Electric Guitar Starter Kit (Blue Burst)',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Brown)',
#  'Cort AD810 Dreadnought Acoustic Guitar with Gig Bag,Tuner,Picks and Strap (Natural Bundle)',
#  'Kaps ST - 1ACM, 6-Strings, Acoustic Guitar , Right-Handed, Wine Red, With Guitar Cover/Bag',
#  'SHARE BY Blueberry R-40- Trussrod Acoustic Guitar Kit with Bag, Strap, One Pack Strings and Picks (Natural)',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Festra 38C, 38 Inch Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks (Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern 38C Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gigbag, Picks, String Set, Strap & Cloth - Black',
#  'Hovner 215 Black F-Cut Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks By K-Retail',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar with Bag, Strings, Pick and Strap (Natural, 6 Strings)',
#  'Photron Acoustic Guitar, 38 Inch Cutaway, PH38C/BK with Picks Only, Black (Without Bag, Strap and Extra Strings)',
#  'Yamaha Classical Guitar C40//02',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Juarez JRZ-ST01 6-String Electric Guitar, Right Handed, Full Black, with Case/Bag and Picks',
#  'Intern INT-38C-SB-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Sunburst, 6 Strings)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Red',
#  'Juarez JRZ-ST01, 6 Strings Electric Guitar, Right Handed with Bag/Case, 2 x Picks (3TS Sunburst)',
#  'Intern INT-38C Sunburst Acoustic Guitar kit with carry bag & picks',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
#  "HOMME STORE 4 String Guitar Children's Musical Instrument Educational Toy Guitar Ukulele Instruments Beginner Musical Sound Toys Best Gift for Children, multi-coloured",
#  'Vault EA40 41 inch Premium Solid Spruce-Top Cutaway Acoustic Guitar',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'HOMME STORE 4 String Guitar Kids Brown Plastic 4 String Acoustic Guitar for Kids Musical Instrument Learning Educational Small Toy for Boys & Girls (Wooden Guitar) (1)',
#  'Medellin 38" Acoustic Guitar Black Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand.',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
#  'Intern INT-38C Acoustic Guitar Kit (Sunburst) with Carry bag, Picks, Strings set and Guitar Strap, Small',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, 3TS Sunburst',
#  'Intern INT-38C-BK-G Cutaway Right Handed Acoustic Guitar Kit, With Bag, Strings, Pick And Strap (Black, 6 Strings)',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand.',
#  'Juarez Acoustic Guitar, 38 Inch Cutaway with Pick Guard, 38CPG with Bag, Strings, Pick and Strap, Black',
#  'Kadence Guitar Acoustica Series A05, Electric Acoustic Guitar, Zebra Wood with Pickup, Inbuilt tuner and Bag (Zebra Wood, Electro Acoustic)',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Sunburst finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Yamaha FSX80C Semi Acoustic Cutaway Guitar with Bag (Natural)',
#  'Medellin 38" Acoustic Guitar Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand. (natural)',
#  'Kadence Acoustica 34” Acoustic Guitar A03 with bag',
#  'Medellin 38" Acoustic Guitar Brown Carbon Fiber Body with FREE Online LEARNING COURSE Durable Matt finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'JUAREZ Arpéggio 104.14 cm (41 Inch) Semi-Acoustic Guitar Kit, Thin Line Body, Spruce Top, with 4 Band EQ, Natural',
#  'JUAREZ Acoustic Guitar 3xE 1st String & 2 Pick Set JRGSE32',
#  'Neowood AT-01A-Guitar Tuner-Black Automatic Digital Tuner (Chromatic: Yes, Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Red',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'Yamaha PACIFICA012 Electric Guitar, Red Metallic',
#  'Revel 38 Inches Cutaway Design Acoustic Guitar with Carry bag and Plectrums. Great tone and Beginner/Learners standard size configuration for all age groups (Natural)',
#  'Yamaha FX280 Semi acoustic Dreadnought Guitar with Bag (Natural)',
#  'Yamaha FS100C Acoustic Guitar, Black',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner)',
#  'Medellin 38" Carbon Fiber Acoustic Guitar with free specailized learning course- MDCF38BK Durable Carbon Fiber Matt Pink finish Body for beginners with handrest, set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE (Special Learning Combo with Guitar)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Yamaha F310 Acoustic Guitar, Tobacco Brown Sunburst',
#  'Ibanez GRG121DX Electric Guitar',
#  'Kadence Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set of Strings, Strap, Picks and Bag (Black EQ, Electric Acoustic)',
#  'Juarez ST38 Electric Guitar Kit/Set, Right Handed, Blue, With Case/Bag & Picks',
#  'Intern 38C Acoustic Steel-string Guitar Premium White Cutaway Design with carry bag, strings, guitar strap and plectrums (INT-38C-WH)',
#  'RockJam RJEG02-SK-BB Electric Guitar Starter Kit (Blue Burst)',
#  'Medellin MED-BLU-C Linden Wood Acoustic Guitar',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Brown)',
#  'Cort AD810 Dreadnought Acoustic Guitar with Gig Bag,Tuner,Picks and Strap (Natural Bundle)',
#  'Kaps ST - 1ACM, 6-Strings, Acoustic Guitar , Right-Handed, Wine Red, With Guitar Cover/Bag',
#  'SHARE BY Blueberry R-40- Trussrod Acoustic Guitar Kit with Bag, Strap, One Pack Strings and Picks (Natural)']

# %%
time.sleep(2)
# Extracting Price of the product
Price = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        price = driver.find_element_by_xpath("//td[@class='a-span12']")
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')

# %%
len(Price)
# Out:
# 180

# %%
Price
# Out:
# ['₹5,399.00',
#  '₹7,348.00',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹5,399.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹2,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹5,499.00',
#  '₹4,999.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,349.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹5,399.00',
#  '₹7,348.00',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹5,399.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹2,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹5,499.00',
#  '₹4,999.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,349.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹5,399.00',
#  '₹7,348.00',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹5,399.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹2,499.00',
#  '₹2,499.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹2,560.00',
#  '-',
#  '-',
#  '-',
#  '₹2,499.00',
#  '₹5,499.00',
#  '₹4,999.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '₹7,349.00',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
time.sleep(2)
# Extracting the Return/Exchange of the product
Exchange = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        Return = driver.find_element_by_xpath("//span[@class='a-declarative']/div/a")
        Exchange.append(Return.text)
    except NoSuchElementException:
        Exchange.append('-')

# %%
len(Exchange)
# Out:
# 180

# %%
Exchange
# Out:
# ['7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement',
#  '7 Days Replacement']

# %%
time.sleep(2)
# Extracting the Expected Delivery of the product
Expected_delivery = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        exp_del = driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
        Expected_delivery.append(exp_del.text)
    except NoSuchElementException:
        Expected_delivery.append('-')

# %%
len(Expected_delivery)
# Out:
# 180

# %%
Expected_delivery
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
time.sleep(2)
# Extracting Availability of the product
Availability = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        availability = driver.find_element_by_xpath('//span[@class="a-size-base a-color-success"]')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
len(Availability)
# Out:
# 180

# %%
Availability
# Out:
# ['',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  '',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  '',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '-',
#  'In stock.']

# %%
time.sleep(2)
# Extracting Other Details of the product
Other_Details = []   #empty list
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        other_details = driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')
        Other_Details.append(other_details.text)
    except NoSuchElementException:
        Other_Details.append('-')

# %%
len(Other_Details)
# Out:
# 180

# %%
Other_Details
# Out:
# ['★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.\n★ Semi Acoustic* (only in Electric Variant) - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.',
#  'QUALITY STRINGS ---The surface is coated with a film coating, which is not easy to rust, which prolongs the use time of the strings and reduces the burden on the fingers when pressing the strings.\nDESIGN --- Simple head design, streamlined curvature makes the head and the body integrated, beautiful. The rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\nSIZE (41 inch)---Suitable for the guitarist over 14 years old, especially the beginners, students or adults.\nADJUSTABLE ACTION----Built-in truss rod can balanced the tension caused by strings or temperature change shrinking, for a straight and durable neck. The adjustable acoustic guitar neck allows your hand to stay in a comfortable position by keeping the strings in a perfect height.\nELECTRO-ACOUSTIC---Built-in preamp for amplified use with volume control, 4 band EQ: bass and treble, integrated tuner for fast and easy tuning.\nACCURATE TUNE---- Kadence guitars employes 18:1 premium machine head, run very smooth, no slack. it can help you to lock the string in position and adjust the pitch more accurate.\nPackage Details:1 pack of Strings, picks, turner, bag, strap and capo',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Finish- Glossy\nSize 38-inch, Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks WITH TRUSS ROD\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Binding: ABS, Finish- Glossy\nTruss Rod for better adjustment of Guitar Action , Size 38-inch,Stlye - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Black Glossy Finish, Number of Frets: 18, Acoustic Guitar with strap, Bag, Strings and 2 Picks\nGreat looks with an innovative design to produce good quality sound\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings',
#  'Great looks with an innovative design to produce sound\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nBlack glossy finish with 18 frets\nIncludes: 38-inch acoustic guitar with strap, bag, string set and 3 picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings.\nBridge material: Plastic\nNote: Product design may slightly vary\nLinden binding and full wood construction with geared tuning, wood frame and steel strings ; Natural glossy finish with 18 frets',
#  'Jumbo Design, 38 Inch Acoustic Steel String Guitar, Black Glossy Finish, Number of Frets: 18\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings\nGreat looks with an innovative design to produce good quality sound\nPackage Includes : Acoustic Guitar with strap, Bag, Strings and 2 Picks',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nCombo includes Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums\nLinden binding and maximum wood construction with geared tuning, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material\nCountry of Origin: China',
#  'Henrix 38C comes with a dual action truss rod which gives you the liberty to adjust the action of your neck in either direction if warped. This is a more advanced design and is used by modern luthiers over the vintage single truss rod. Thus, a warp in the neck in either direction can be fixed. This extends your guitars life by making it more resilient to climate changes. Guitars without this dual action truss rod need hefty repair jobs to fix neck warps.\nThe 38C comes with high precision(18:1), metal laminated diecast tuners. This allows you an effortless & precise tuning. This is a preferred tuning machine head preferred by professional guitarists. These are best for long jam sessions, as they stay in tune for longer.\nA feature normally found only in high-end pro guitars, binding extends your guitar life by protecting the edges of the wood from impact and, particularly where end grain would be exposed to moisture damage.\nWe add an accessory pack with this guitar which makes this a one-stop solution for any beginner. The pack includes - A guitar gig bag, strap, three plectrums (picks), extra strings set, string winder & a microfibre guitar polishing cloth.\nGuitar Finish - Laminated Gloss | Top - Basswood | Back/Sides - Basswood | Fretboard - Syntheticwood | Bridge: Carbon Fibre /ABS 18 Frets | Diecast Tuners | Scale: 643 mm | Colour: Natural, Sunburst, Red-Burst & Black | Body Type : Cutaway\nHENRIX 38-C Acoustic Guitar Pack Contains:-Gig bag, Henrix 38-C Acoustic Guitar, Polishing Cloth, 3 Plectrums, Extra String Set with a string winder',
#  '41 inch F- Cut Acoustic Guitar, Fretboard : Rose Wood, String : Steel\nGreat looks with an innovative design to produce good sound\nAdjustable bridge and reinforced Truss Rod\nInbuilt pick up to plug and play with amplifier, Bag, Strap, 1 Set of Extra Strings and 2 Picks included',
#  'Black glossy finish, number of frets: 18, Acoustic guitar and 2 Picks\nGreat looks with an innovative design to produce quality sound, Pickup Present: Yes\nFinger board: Linden wood, fretboard - Ebony wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with 2 Picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nCountry of Origin: China',
#  'Number of Frets: 18\nAcoustic guitar with strap, bag, strings and 2 picks\nGreat looks with an innovative design to produce quality sound\nFinger Board: Linden wood\nFretboard: Ebony wood\nSize: 38 inches, cutaway\nLinden binding and full wood construction with geared tuning, wood frame and steel strings',
#  'Great looks with an innovative design to produce sound. Pickup Battery Included: No\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nRed burst glossy finish with 18 frets\nIncludes: 38-inch acoustic guitar with strap, bag, string set and 3 picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nBridge material: Plastic\nNote: Product design may slightly vary',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.\n★ Semi Acoustic* (only in Electric Variant) - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.',
#  'Number of Frets: 18\nGreat looks with an innovative design to produce quality sound\nFingerboard: Linden wood\nFretboard: Ebony wood\nSize: Cutaway, 38 inches\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nChrome die cast machine head',
#  'Full-size classical designed for beginners\nMeranti body wood\nSpruce top\n22.8-inch scale length\nDovetail neck joint',
#  '38 inches cutaway revolutionary design and configuration to produce marvellous sound\nHi gloss black color finish. String Material : Nickel\nGuitar bundled with accessories like smart strap, bag, strings set and 3 picks\nEasy to hold for stress-free playing and ultra-portable\nQuality linden wood soundboard for unsurpassed resonance',
#  '38 inches cutaway revolutionary design and configuration to produce marvellous sound\nHi gloss sunburst color finish\nGuitar bundled with accessories like smart strap, bag, strings set and 3 picks\nEasy to hold for stress-free playing and ultra-portable\nQuality linden wood soundboard for unsurpassed resonance\nIntern hi gloss 38-inch guitar, 1 set string, bag, strap and 3 picks\nCountry of Origin: China',
#  'Black glossy finish, number of frets: 18, acoustic guitar with strap, bag, strings and 2 picks. Hand Orientation: Right\nGreat looks with an innovative design to produce sound\nFinger board: Linden wood, fretboard - Ebony wood, size: 38 inches, cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nAn able acoustic guitar, its neck material is made from Linden Wood, bridge material is made from plastic, finger board and back material is made from Linden Wood, string is made from nylon, and sides material is made from Linden\nPlease email brand at support@p to get product serviced/Replaced',
#  "Made in Yamaha Music India factory\nBrand: Yamaha\nStainless Steel\nHigh durability and stability proven by Yamaha's quality standard\nConcert body cutaway with comfortable playability for beginners",
#  "PROVIDES SCREEN FREE FUN: A junior scale 4 string guitar perfect for use on lessons, recitals, band rehearsals, on-stage performances or when practicing at home. The mini guitar can attract the interests of kids, and reduce their dependency on the phone, computer, or other electronics.\nGREAT FOR BEGINNERS: It has a traditional classic body style great for beginners and children learning to play guitar. Give your best performance whether you're in the music studio or out at a bonfire with friends. Take your music with you.\nENJOY MUSIC ANYTIME: Helps kids have fun and stimulate and develop their talent & interest. This guitar is 24 inches in length.; Please Note: This is an assortment pack, so accessories and design may vary\nThis Acoustic Guitar makes a great gift for kids. Lightweight, easy to hold, and has a nice appearance.This is not a professionally manufactured Guitar, just a toy for Children.Recommended for ages above 6 years.This guitar has good sound quality & good wooden finishing.It is made up of good quality plastic & is good for playing and learning.\nA PERFECT GIFT: Helps kids have fun and stimulate and develop their talent & interest. This guitar is 24 inches in length.; Please Note: This is an assortment pack, so accessories and design may vary",
#  'Solid Spruce Top - Solid Wood-Top guitars provide a richer sound and greater resonance than laminate or ply tops, and are normally found only on premium priced guitars. The end result is the Vault EA40 providing rich natural wood resonance, yet priced at a fraction of a typical solid-top guitar.\nVault EA40 comes with a dual action truss rod which gives you the liberty to adjust the action of your neck in either direction if warped. This is a more advanced design and is used by modern luthiers over the vintage single truss rod. Thus, a warp in the neck in either direction can be fixed.\nVault EA40 comes with high precision (18:1), chrome-plated die-cast tuners. This allows you an effortless & precise tuning. This is a preferred tuning machine head preferred by a lot of professional guitarists, as they stay in tune for longer.\nAcoustic Steel String Guitar | Truss Rod | Cutaway\nSize 41” | Finish - Natural | Top - Solid Spruce\nBack - Mahogany Laminate | Sides - Mahogany Laminate\nFret Board - Rosewood | 20 Frets\nDiecast Tuners | Scale: 1016 mm',
#  '-',
#  'The Cort AD810 Dreadnought Acoustic Guitar has been designed to accommodate a whole gamut of musical styles from indie and punk to folk and rock. If you wish to explore genres other than the one you specialize in, this instrument is your best bet, as it offers versatile playability. The dreadnought body profile of this guitar makes it well-suited for flatpickers. The top of the AD810 is constructed from spruce for durability. This tonewood offers fast sound transmission and therefore significant\nThe dovetail neck joint of the Cort AD810 Dreadnought Acoustic Guitar ensures a strong coupling between the body and neck, thus providing optimum control. In addition, the mahogany construction of the neck translates into smooth, well-rounded tones. The fretboard is crafted from rosewood to add an element of spark to the guitar’s voice. This tonewood produces sounds that extended across both ends of the tonal spectrum. As a result, this guitar is well-suited for any musical situation.\nThe high-quality coating on the strings of this guitar offers protection from moisture and dirt to help them stand the test of time. Thus, you obtain enhanced playability when practicing attack-heavy styles on this guitar.\nThe Cort AD810 Dreadnought Acoustic Guitar meets the needs of fingerstyle players and flatpickers alike. It helps musicians to expand their creative sensibilities by letting them experiment with different musical genres.\nFeatures: Dovetail neck joint for smooth transfer of vibrational energy | Spruce top for stiffness and fast sound transmission | Mahogany back and sides Rosewood fretboard | White dot inlays | Die-cast chrome tuners | Scooped rosewood bridge',
#  'Top: Spruce back/sides\nMahogany neck\nNato fret board\nRosewood bridge\nSnorkeling frets: 20\nOpen chrome tuners\nFinishes: black',
#  'Great looks with an innovative design to produce sound\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nSunburst glossy finish with 18 frets\nIncludes: 38-inch acoustic guitar with strap, bag, string set and 3 picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nBridge material: Plastic\nNote: Product design may slightly vary',
#  'Black glossy finish, number of frets: 18, acoustic guitar with strap, bag, strings and 2 picks , Great looks with an innovative design to produce sound\nProduct Dimensions: 96 x 43 x 12 cm ,Item Weight: 2 Kg\nFinger board: Linden wood, fretboard - Ebony wood, size: 38 inches, cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings',
#  'ACOUSTIC-ELECTRIC GUITAR: The first choice from the house of Kadence comes from the Acoustica series. Our semi acoustic-electric guitars are built to have great sound quality, high durability, and increased ease of use for both beginners as well as professionals. The 40-inch stature makes it easy to handle and carry around without compromising on the sound quality. Made from zebra wood, our electro acoustic guitars come with a pickup, inbuilt tuner and bag. Everything you need to start playing.\nADJUSTABLE ACTION: Built-in truss rod can balance the tension caused by strings or temperature change shrinking, for a straight and durable neck. The adjustable electric acoustic guitars neck allows your hand to stay in a comfortable position by keeping the strings at a perfect height. Kadence semi acoustic guitar electric has a built-in preamp for amplified use with volume control, 2 band EQ, bass and treble, integrated tuner for fast and easy tuning. Making it perfect for juniors and adults.\nACCURATE TUNE: The 40inch cutaway guitar acoustic electric employs an 18:1 premium machine head that runs very smooth with no slack. It can help you to lock the string in position and adjust the pitch more accurately. The Kadence guitar is easy to tune and hold tune after the first tune-up of strings. Kadence guitars have better bass, better volume, and fuller sound. Suited for all styles of music, and guitarists over 14 years old, especially beginners, students, or adults.\nEASY CUTAWAY DESIGN TO PLAY: The cutaway design of this acoustic guitar allows you easier access to the upper frets. Classical unique design allows you to easily change strings and makes sure the playing tone is great. Elegant inlay provides a classic, acoustic look and the cutaway shape allows you to reach higher on the fret to reach high notes. Place the included pickguard underneath the guitar soundhole to protect from pick scratches while playing. The strings are soft and smooth to touch.\nQUALITY INSTRUMENTS FOR EVERYDAY: With a wide variety of musical instruments, Kadence is committed to developing better comfortable and functional acoustic guitars, providing quality services and excellent products. With quality instruments from Kadence, you’ll have a constant companion for life. Regardless of what you love to play, just make sure to express yourself. Whatever your age or skill level, our guitars electric will make sure all your musical desires are fulfilled.',
#  '-',
#  'Yamaha FSX80C semi acoustic guitar With a padded Guitar bag if purchased from Chennai Musicals as seller\nFingerboard MaterialRosewood Fingerboard RadiusR400mm (15 3/4") Bridge MaterialRosewood\nBody ShapeConcert Cutaway Scale Length634mm (25”) Body Length497mm (19 9/16") Total Length1021mm (40 3/16") Body Width380mm (14 15/16")\nElectronicsSYSTEM68 + ART 1way Pickup ControlsVol/Tone/Tuner ConnectionsLINE OUT\nBUILD TO DELIVER RICH ACOUSTIC TONE & RESONANCE\nCONCERT BODY CUTAWAY FOR OUTSTANDING COMFORT\nART PICKUP TO RECREATE NATURAL TONE AND DYNAMICS',
#  'Black Glossy Finish, Number of Frets: 18, Acoustic Guitar with strap, Bag, Strings and 2 Picks\nGreat looks with an innovative design to produce good quality sound\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings',
#  '♫ CARBON FIBER GUITAR: As a substitute for tonewood, carbon fiber has the resembling tonal traits. This Guitar is made of a carbon fiber composite material, maximally transferring the string vibration energy into great acoustics performance, loud and balanced.\n♫ STABLE AND RELIABLE: Unlike wood, carbon fiber never warps, cracks, or scratches, staying consistent across different temperature and humidity conditions. Take it on travels from hills to desert and everywhere in between. It stays the same, sounds the same.\n♫ SOUND: This carbon fiber guitar has a sound people describe as very rich, loud and resonant with a nice balanced tone. Medellin guitars compare favorably to acoustic guitars from all the top wood and carbon fiber brands for beginners.\n♫ WHAT YOU GET: Each Medellin Carbon Fiber guitar is packaged with a set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE. (Special Learning Combo with Guitar)\n♫ Learn on the go: You get a free specialised learning course with the instrument. The access key you receive with the guitar shall be claimed to start the free learning course. Guitar Course starts from 15th December 2021.',
#  '-',
#  '♫ CARBON FIBER GUITAR: As a substitute for tonewood, carbon fiber has the resembling tonal traits. This Guitar is made of a carbon fiber composite material, maximally transferring the string vibration energy into great acoustics performance, loud and balanced.\n♫ STABLE AND RELIABLE: Unlike wood, carbon fiber never warps, cracks, or scratches, staying consistent across different temperature and humidity conditions. Take it on travels from hills to desert and everywhere in between. It stays the same, sounds the same.\n♫ SOUND: This carbon fiber guitar has a sound people describe as very rich, loud and resonant with a nice balanced tone. Medellin guitars compare favorably to acoustic guitars from all the top wood and carbon fiber brands for beginners.\n♫ WHAT YOU GET: Each Medellin Carbon Fiber guitar is packaged with a set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE. (Special Learning Combo with Guitar)\n♫ Learn on the go: You get a free specialised learning course with the instrument. The access key you receive with the guitar shall be claimed to start the free learning course. Guitar Course starts from 15th December 2021.',
#  'Traditional Western Body\nSpruce Top\nYamaha Quality in an Affordable Price\nBridge Material:-Rosewood',
#  'Glossy finish, Number of frets - 18, 38 Inch Acoustic Guitar with Dual Action Truss Rod which gives you the liberty to adjust the action of your neck in either direction if warped.\nMaterial : Top, Back, Sides & Neck - Linden Solid Wood, Fretboard & Bridge - ABS, Machine Head : Chrome Open, Stainless Steel Copper Wound Strings\nLinden binding and full wood construction with geared tuning, wooden frame and steel strings. Features a sturdy top with smooth curves, promoting comfort during playing. This solid wood produces a smooth and rich sound ideal for rock, folk, country, and every genre in between!\nLoosening a truss rod (turning counter-clockwise) adds relief to (decreases tension on) the neck which results in increased (higher) string action height. . This reduces relief, lowering the string action (height of the strings over the frets). Turn the nut clockwise to tighten the rod.\nIncluded components: Acoustic Guitar with Strap, Bag, Strings, Truss Rod Wrench/Allen Key and 2 Plectrums',
#  '*FIRST CHOICE - Quality, Attractive, and Affordable, 34 inches acoustic guitar is great value for money that represent the Mahogany guitar. Perfect size for adults, beginners, student and guitarist\n*BALANCED SOUND - Handcrafted body and "X" bracing structure offers both bright and warm tone that has excellent acoustic properties and great extension and response\n*SMOOTH PLAY - High density wood fingerboard and bridge offers both sturdy construct and smooth touch that you can roll over the nickel silver frets freely. The Sealed Gear machine head keeps the strings in tune, and the dual - action truss rod allows fine adjustment of the guitar neck\n*EXQUISITE LOOK - With state of art crafting and assembling, hand rubbed finish, retro style, silky smooth body lines, white ABS binding, all together present an exquisite artwork',
#  'Yamaha FSX80C semi acoustic guitar With a padded Guitar bag if purchased from Chennai Musicals as seller\nFingerboard MaterialRosewood Fingerboard RadiusR400mm (15 3/4") Bridge MaterialRosewood\nBody ShapeConcert Cutaway Scale Length634mm (25”) Body Length497mm (19 9/16") Total Length1021mm (40 3/16") Body Width380mm (14 15/16")\nElectronicsSYSTEM68 + ART 1way Pickup ControlsVol/Tone/Tuner ConnectionsLINE OUT\nBUILD TO DELIVER RICH ACOUSTIC TONE & RESONANCE\nCONCERT BODY CUTAWAY FOR OUTSTANDING COMFORT\nART PICKUP TO RECREATE NATURAL TONE AND DYNAMICS',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Finish- Glossy\nSize 38-inch, Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Black Guitar Tuner\nCompact size clip-on tuner for chromatic/ guitar/ bass/ ukulele/ violin.\nLCD display, 2 colors backlight: green- in tune, white- out of tune.\nRotatable design, allows you to have the best viewing angle.',
#  'Solid agathis body\nMaple neck\nRosewood fingerboard\nOne humbucker/2 single-coil pickups\nChrome tuners\nWhite pickguard. Vintage-style chrome tremolo',
#  'Juarez Acoustic Guitar 3xE 1st String & 2 Pick Set JRGSE32\nModel No: JRGSE32\nitem package dimensions: 60.0 L x 30.0 W x 60.0 H (millimeters)\nitem weight: 60.0 grams',
#  '♫ CARBON FIBER GUITAR: As a substitute for tonewood, carbon fiber has the resembling tonal traits. This Guitar is made of a carbon fiber composite material, maximally transferring the string vibration energy into great acoustics performance, loud and balanced.\n♫ STABLE AND RELIABLE: Unlike wood, carbon fiber never warps, cracks, or scratches, staying consistent across different temperature and humidity conditions. Take it on travels from hills to desert and everywhere in between. It stays the same, sounds the same.\n♫ SOUND: This carbon fiber guitar has a sound people describe as very rich, loud and resonant with a nice balanced tone. Medellin guitars compare favorably to acoustic guitars from all the top wood and carbon fiber brands for beginners.\n♫ WHAT YOU GET: Each Medellin Carbon Fiber guitar is packaged with a set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE. (Special Learning Combo with Guitar)\n♫ Learn on the go: You get a free specialised learning course with the instrument. The access key you receive with the guitar shall be claimed to start the free learning course. Guitar Course starts from 15th December 2021.',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Semi Acoustic - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.\n★ Accessories - Strap, Strings, Picks and Bag Included.',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.',
#  '-',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design, String Material: Nickel\nCombo includes Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums\nLinden binding and maximum wood construction with geared tuning, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material\nCountry of Origin: China',
#  'Thin Line Sleek Body, Glossy finish, Number of frets - 21, 41 Inch Acoustic Guitar with Dual Action Truss Rod which gives you the liberty to adjust the action of your neck in either direction if warped.\nWhite+Black line ABS Binding and full wood construction with geared tuning, wooden frame and Alice Brand Stainless steel copper alloy strings. Features a sturdy top with smooth curves, promoting comfort during playing. This solid wood produces a smooth and rich sound ideal for rock, folk, country, and every genre in between!\nLoosening a truss rod (turning counter-clockwise) adds relief to (decreases tension on) the neck which results in increased (higher) string action height. This reduces relief, lowering the string action (height of the strings over the frets). Turn the nut clockwise to tighten the rod.\n6 Stainless Steel Alice Brand strings especially for beginners. Wound strings are made of copper alloy. Stainless steel plain string, steel core, copper alloy winding, anti-rust coating.\nMaterial : Top- Spruce Wood, Back, Sides - Linden Solid Wood, Neck - Okoume, Fretboard & Bridge - Rosewood, Machine Head : Chrome Diecast, Stainless Steel Copper Wound Strings\n4 Band Equalizer - EQ:7545R',
#  'Great looks with an innovative design for easy in playing and learning. Easy access to all notes and flexible grip for all posters and heights\nBest woods combination with basswood, linden and engineered wood used to produce vibrant rich tone\nIncludes: 38-inch acoustic guitar with bag and 3 picks\n1 year warranty',
#  'ACOUSTIC-ELECTRIC GUITAR: The black acoustic guitar from the house of Kadence comes from the Frontier series. Our semi acoustic-electric guitars are built to have great sound quality, high durability, and increased ease of use for both beginners as well as professionals. The 41-inch stature makes it easy to handle and carry around without compromising on the sound quality. Made from rosewood, our guitar acoustic electric comes with a strap, strings, picks, capo, tuner, and bag.\nADJUSTABLE ACTION: Built-in truss rod can balance the tension caused by strings or temperature change shrinking, for a straight and durable neck. The adjustable black acoustic electric guitar neck allows your hand to stay in a comfortable position by keeping the strings at a perfect height. Frontier series electric acoustic guitars have a built-in preamp for amplified use with volume control, 4 band EQ, bass, mid, treble, and press for fast and easy tuning. Perfect for juniors and adults.\nDURABLE STRINGS: Built for great sound quality, high durability, and increased ease of use. The surface is coated with a bronze coating which does not rust easily and prolongs the use of the strings. The tuning pegs are engineered for good sound quality. The tuning keys are smooth and easy to adjust to keep the guitar in tune. Kadence guitars have better bass, volume, and fuller sound. Great for all styles of music, and guitarists over 14 years old, especially beginners, students, or pros.\nEASY CUTAWAY DESIGN TO PLAY: The cutaway design of this guitar electric acoustic allows you easier access to the upper frets. The high gloss finish, simple head design, streamlined cutaway curvature makes the head and the body integrated, beautiful. The Indian rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission. Place the included pickguard underneath the guitar soundhole to protect from pick scratches while playing. The strings are soft to touch.\nQUALITY INSTRUMENTS FOR EVERYDAY: With a wide variety of musical instruments, Kadence is committed to developing better comfortable and functional acoustic guitars, providing quality services and excellent products. With quality instruments from Kadence, you’ll have a constant companion for life. Regardless of what you love to play, just make sure to express yourself. Whatever your age or skill level, our semi acoustic guitar will make sure all your musical desires are fulfilled.',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Conditioned wooden Body with Rosewood finger board, Ebony fretboard and 38-inch cutaway design\nCombo includes Premium White colored Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums, Strings and Guitar strap\nMaximum wood construction with geared tuning, pine-wood bracing, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material',
#  'Black Glossy Finish, Number of Frets: 18, Acoustic Guitar with strap, Bag, Strings and 2 Picks\nGreat looks with an innovative design to produce good quality sound\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings',
#  'Steel strung full scale neck\nSlim line contoured body for comfortable playability and a rich tone\nIncludes sturdy guitar stand\nAlso includes tuner, gig bag, strap, picks and strings\nFree online lessons\nCountry of Origin: China',
#  'Type - Acoustic Guitar with cutaway. Specially made for India. Designed in Japan and the best guitar for beginners. It comes specially checked by experts.\nFingerboard material - rosewood. Extremely comfortable guitar. Teachers all over India recommend this guitar. It is comparable with all the leading brands in the world.\nTop - Spruce. Seasoned Spruce wood is used on the top, back and sides of the guitar. These woods are sourced thoughtfully making it one of the leading acoustic guitars.\nNumber of frets - 20. The fretboard is smooth making it easy to play the guitar. The cutaway option provides easy access to the higher frets when necessary.\nNumber of strings - 6. The guitar is easy to tune due to the high quality tuning pegs used. The bridge and the overall construction is extremely well done. You will be very happy with this guitar.',
#  'Acoustic Guitar 38 inches Carbon fibre Acoustic 6 steel string Folk Guitar with higher natural tone resonance and durability. Durable and long lasting with Carry bag, strings, picks & strap. For all age-groups starting 7 years and levels of skill from beginner to semi-professionals\nGreat looks with an innovative design to produce quality sound\nEmploying the machine binding and fine handcrafting production techniques with commitment to environment using harmless and nature binding colours. High quality excellent glossy finish.\nSpecially crafted fretboard for smooth finger movement lasting at least 10 times longer than the Chinese linden wood. 5 ply box packaging for avoiding any damage to the instrument in transit\nBag with stylish nylon made and long lasting material\nPerfect combination of fibre, machine heads, strings, frets and other components for vibrant outstanding sound quality. Selected Configuration mPerfect combination of fibre, machine heads, strings, frets and other components for vibrant outstanding sound quality. Selected Configuration meant for advanced learners and performers.eant for advanced learners and performers.\nLinden binding and full wood construction with geared tuning, wood frame and steel strings',
#  'Solid agathis body\nMaple neck, Body Finish: Gloss Polyurethane\nRosewood fingerboard\nOne humbucker/2 single-coil pickups',
#  "4-string Guitar Toy for Kids with Adjustable Tuning Knobs for Intellectual Development and also to develop talent and interest in kids.\nThis guitar has good sound quality & good wooden finishing.It is made up of good quality plastic & is good for playing and learning.\nProvides screen free fun: A junior scale 4 string guitar perfect for use on lessons, recitals, band rehearsals, on-stage performances or when practicing at home. The mini guitar can attract the interests of kids, and reduce their dependency on the phone, computer, or other electronics.\nGreat for beginners: It has a traditional classic body style great for beginners and children learning to play guitar. Give your best performance whether you're in the music studio or out at a bonfire with friends. Take your music with you.\nThis Acoustic Guitar makes a great gift for kids. Lightweight, easy to hold, and has a nice appearance.This is not a professionally manufactured Guitar, just a toy for Children.",
#  'Material: Top: Spruce, Side & Back: - linden wood, Fingerboard:- Engineered Wood\nBridge：Engineered Wood, Neck: Okoume wood, Machine head: Chrome die cast, Binding: ABS, Finish- High Glossy\nIncludes: 40", acoustic guitar with Belt, bag, string set and 2 picks With TRUSS ROD adjustment support\nTruss Rod for better adjustment of Guitar Action , Size 40" ,Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Has 39-inch Cut-A-Way Guitar, Cream Binding Top and Head\nMaterial : Rosewood fingerboard and Bridge, Toon Wood Body and Neck, Pine Wood Top\nColour : Wine Red in High Gloss Finish, Chrome Keys\nPackage Content : 1 Guitar, Guitar Cover/Bag, Strings Pack, String winder and 5 Plectrums',
#  'Material: Top: Spruce, Side & Back: - Bass wood, Fingerboard:- Rosewood\nBridge：Rosewood, Neck: Okoume wood, Machine head: Chrome die cast, Binding: ABS, Finish- Satin\nIncludes: 40 Inch Acoustic guitar with Belt, bag, string set and 2 picks With TRUSS ROD adjustment support\nTruss Rod for better adjustment of Guitar Action , Size 40" ,Style - Cutaway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.\n★ Semi Acoustic* (only in Electric Variant) - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.',
#  'QUALITY STRINGS ---The surface is coated with a film coating, which is not easy to rust, which prolongs the use time of the strings and reduces the burden on the fingers when pressing the strings.\nDESIGN --- Simple head design, streamlined curvature makes the head and the body integrated, beautiful. The rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\nSIZE (41 inch)---Suitable for the guitarist over 14 years old, especially the beginners, students or adults.\nADJUSTABLE ACTION----Built-in truss rod can balanced the tension caused by strings or temperature change shrinking, for a straight and durable neck. The adjustable acoustic guitar neck allows your hand to stay in a comfortable position by keeping the strings in a perfect height.\nELECTRO-ACOUSTIC---Built-in preamp for amplified use with volume control, 4 band EQ: bass and treble, integrated tuner for fast and easy tuning.\nACCURATE TUNE---- Kadence guitars employes 18:1 premium machine head, run very smooth, no slack. it can help you to lock the string in position and adjust the pitch more accurate.\nPackage Details:1 pack of Strings, picks, turner, bag, strap and capo',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Finish- Glossy\nSize 38-inch, Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks WITH TRUSS ROD\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Binding: ABS, Finish- Glossy\nTruss Rod for better adjustment of Guitar Action , Size 38-inch,Stlye - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Black Glossy Finish, Number of Frets: 18, Acoustic Guitar with strap, Bag, Strings and 2 Picks\nGreat looks with an innovative design to produce good quality sound\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings',
#  'Great looks with an innovative design to produce sound\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nBlack glossy finish with 18 frets\nIncludes: 38-inch acoustic guitar with strap, bag, string set and 3 picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings.\nBridge material: Plastic\nNote: Product design may slightly vary\nLinden binding and full wood construction with geared tuning, wood frame and steel strings ; Natural glossy finish with 18 frets',
#  'Jumbo Design, 38 Inch Acoustic Steel String Guitar, Black Glossy Finish, Number of Frets: 18\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings\nGreat looks with an innovative design to produce good quality sound\nPackage Includes : Acoustic Guitar with strap, Bag, Strings and 2 Picks',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nCombo includes Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums\nLinden binding and maximum wood construction with geared tuning, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material\nCountry of Origin: China',
#  'Henrix 38C comes with a dual action truss rod which gives you the liberty to adjust the action of your neck in either direction if warped. This is a more advanced design and is used by modern luthiers over the vintage single truss rod. Thus, a warp in the neck in either direction can be fixed. This extends your guitars life by making it more resilient to climate changes. Guitars without this dual action truss rod need hefty repair jobs to fix neck warps.\nThe 38C comes with high precision(18:1), metal laminated diecast tuners. This allows you an effortless & precise tuning. This is a preferred tuning machine head preferred by professional guitarists. These are best for long jam sessions, as they stay in tune for longer.\nA feature normally found only in high-end pro guitars, binding extends your guitar life by protecting the edges of the wood from impact and, particularly where end grain would be exposed to moisture damage.\nWe add an accessory pack with this guitar which makes this a one-stop solution for any beginner. The pack includes - A guitar gig bag, strap, three plectrums (picks), extra strings set, string winder & a microfibre guitar polishing cloth.\nGuitar Finish - Laminated Gloss | Top - Basswood | Back/Sides - Basswood | Fretboard - Syntheticwood | Bridge: Carbon Fibre /ABS 18 Frets | Diecast Tuners | Scale: 643 mm | Colour: Natural, Sunburst, Red-Burst & Black | Body Type : Cutaway\nHENRIX 38-C Acoustic Guitar Pack Contains:-Gig bag, Henrix 38-C Acoustic Guitar, Polishing Cloth, 3 Plectrums, Extra String Set with a string winder',
#  '41 inch F- Cut Acoustic Guitar, Fretboard : Rose Wood, String : Steel\nGreat looks with an innovative design to produce good sound\nAdjustable bridge and reinforced Truss Rod\nInbuilt pick up to plug and play with amplifier, Bag, Strap, 1 Set of Extra Strings and 2 Picks included',
#  'Black glossy finish, number of frets: 18, Acoustic guitar and 2 Picks\nGreat looks with an innovative design to produce quality sound, Pickup Present: Yes\nFinger board: Linden wood, fretboard - Ebony wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with 2 Picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nCountry of Origin: China',
#  'Number of Frets: 18\nAcoustic guitar with strap, bag, strings and 2 picks\nGreat looks with an innovative design to produce quality sound\nFinger Board: Linden wood\nFretboard: Ebony wood\nSize: 38 inches, cutaway\nLinden binding and full wood construction with geared tuning, wood frame and steel strings',
#  'Great looks with an innovative design to produce sound. Pickup Battery Included: No\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design\nRed burst glossy finish with 18 frets\nIncludes: 38-inch acoustic guitar with strap, bag, string set and 3 picks\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nBridge material: Plastic\nNote: Product design may slightly vary',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.\n★ Semi Acoustic* (only in Electric Variant) - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.',
#  'Number of Frets: 18\nGreat looks with an innovative design to produce quality sound\nFingerboard: Linden wood\nFretboard: Ebony wood\nSize: Cutaway, 38 inches\nLinden binding and full wood construction with geared tuning, wood frame and steel strings\nChrome die cast machine head',
#  'Full-size classical designed for beginners\nMeranti body wood\nSpruce top\n22.8-inch scale length\nDovetail neck joint',
#  '38 inches cutaway revolutionary design and configuration to produce marvellous sound\nHi gloss black color finish. String Material : Nickel\nGuitar bundled with accessories like smart strap, bag, strings set and 3 picks\nEasy to hold for stress-free playing and ultra-portable\nQuality linden wood soundboard for unsurpassed resonance',
# ...
#  '*FIRST CHOICE - Quality, Attractive, and Affordable, 34 inches acoustic guitar is great value for money that represent the Mahogany guitar. Perfect size for adults, beginners, student and guitarist\n*BALANCED SOUND - Handcrafted body and "X" bracing structure offers both bright and warm tone that has excellent acoustic properties and great extension and response\n*SMOOTH PLAY - High density wood fingerboard and bridge offers both sturdy construct and smooth touch that you can roll over the nickel silver frets freely. The Sealed Gear machine head keeps the strings in tune, and the dual - action truss rod allows fine adjustment of the guitar neck\n*EXQUISITE LOOK - With state of art crafting and assembling, hand rubbed finish, retro style, silky smooth body lines, white ABS binding, all together present an exquisite artwork',
#  'Yamaha FSX80C semi acoustic guitar With a padded Guitar bag if purchased from Chennai Musicals as seller\nFingerboard MaterialRosewood Fingerboard RadiusR400mm (15 3/4") Bridge MaterialRosewood\nBody ShapeConcert Cutaway Scale Length634mm (25”) Body Length497mm (19 9/16") Total Length1021mm (40 3/16") Body Width380mm (14 15/16")\nElectronicsSYSTEM68 + ART 1way Pickup ControlsVol/Tone/Tuner ConnectionsLINE OUT\nBUILD TO DELIVER RICH ACOUSTIC TONE & RESONANCE\nCONCERT BODY CUTAWAY FOR OUTSTANDING COMFORT\nART PICKUP TO RECREATE NATURAL TONE AND DYNAMICS',
#  'Material: Top: linden wood, Side & Back: - linden wood, Fingerboard:- ABS\nIncludes: 38-inch, acoustic guitar with Belt, bag, string set and 2 picks\nBridge：ABS, Neck: Catalpa wood, Machine head: Open, Finish- Glossy\nSize 38-inch, Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Black Guitar Tuner\nCompact size clip-on tuner for chromatic/ guitar/ bass/ ukulele/ violin.\nLCD display, 2 colors backlight: green- in tune, white- out of tune.\nRotatable design, allows you to have the best viewing angle.',
#  'Solid agathis body\nMaple neck\nRosewood fingerboard\nOne humbucker/2 single-coil pickups\nChrome tuners\nWhite pickguard. Vintage-style chrome tremolo',
#  'Juarez Acoustic Guitar 3xE 1st String & 2 Pick Set JRGSE32\nModel No: JRGSE32\nitem package dimensions: 60.0 L x 30.0 W x 60.0 H (millimeters)\nitem weight: 60.0 grams',
#  '♫ CARBON FIBER GUITAR: As a substitute for tonewood, carbon fiber has the resembling tonal traits. This Guitar is made of a carbon fiber composite material, maximally transferring the string vibration energy into great acoustics performance, loud and balanced.\n♫ STABLE AND RELIABLE: Unlike wood, carbon fiber never warps, cracks, or scratches, staying consistent across different temperature and humidity conditions. Take it on travels from hills to desert and everywhere in between. It stays the same, sounds the same.\n♫ SOUND: This carbon fiber guitar has a sound people describe as very rich, loud and resonant with a nice balanced tone. Medellin guitars compare favorably to acoustic guitars from all the top wood and carbon fiber brands for beginners.\n♫ WHAT YOU GET: Each Medellin Carbon Fiber guitar is packaged with a set of Strings, Strap, Bag, 3 Picks, Capo, Guitar Wall Hanging Stand and Free GUITAR LEARNING COURSE. (Special Learning Combo with Guitar)\n♫ Learn on the go: You get a free specialised learning course with the instrument. The access key you receive with the guitar shall be claimed to start the free learning course. Guitar Course starts from 15th December 2021.',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Semi Acoustic - Built-in preamp for amplified use with volume control, 4 band EQ: bass, mid, treble and press.\n★ Accessories - Strap, Strings, Picks and Bag Included.',
#  '★ Design - The High Gloss finish, Simple head design, Streamlined Cutaway Curvature makes the head and the body integrated, beautiful.\n★ Size (40 inch) - Suitable for the guitarist over 10 years old, especially the beginners, students or adults.\n★ Quality Strings -The surface is coated with a bronze coating which doest rust easliy and prolongs the use of the strings.\n★ Adjustable Action - Built-in truss rod helps balance the tension caused by strings or temperature change, for a straight and durable neck.\n★ Bridge - The Indian Rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission.\n★ Accessories - Strap, Strings, Picks and Bag Included.',
#  '-',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Linden wood finger board with ebony wood fretboard and 38-inch cutaway design, String Material: Nickel\nCombo includes Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums\nLinden binding and maximum wood construction with geared tuning, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material\nCountry of Origin: China',
#  'Thin Line Sleek Body, Glossy finish, Number of frets - 21, 41 Inch Acoustic Guitar with Dual Action Truss Rod which gives you the liberty to adjust the action of your neck in either direction if warped.\nWhite+Black line ABS Binding and full wood construction with geared tuning, wooden frame and Alice Brand Stainless steel copper alloy strings. Features a sturdy top with smooth curves, promoting comfort during playing. This solid wood produces a smooth and rich sound ideal for rock, folk, country, and every genre in between!\nLoosening a truss rod (turning counter-clockwise) adds relief to (decreases tension on) the neck which results in increased (higher) string action height. This reduces relief, lowering the string action (height of the strings over the frets). Turn the nut clockwise to tighten the rod.\n6 Stainless Steel Alice Brand strings especially for beginners. Wound strings are made of copper alloy. Stainless steel plain string, steel core, copper alloy winding, anti-rust coating.\nMaterial : Top- Spruce Wood, Back, Sides - Linden Solid Wood, Neck - Okoume, Fretboard & Bridge - Rosewood, Machine Head : Chrome Diecast, Stainless Steel Copper Wound Strings\n4 Band Equalizer - EQ:7545R',
#  'Great looks with an innovative design for easy in playing and learning. Easy access to all notes and flexible grip for all posters and heights\nBest woods combination with basswood, linden and engineered wood used to produce vibrant rich tone\nIncludes: 38-inch acoustic guitar with bag and 3 picks\n1 year warranty',
#  'ACOUSTIC-ELECTRIC GUITAR: The black acoustic guitar from the house of Kadence comes from the Frontier series. Our semi acoustic-electric guitars are built to have great sound quality, high durability, and increased ease of use for both beginners as well as professionals. The 41-inch stature makes it easy to handle and carry around without compromising on the sound quality. Made from rosewood, our guitar acoustic electric comes with a strap, strings, picks, capo, tuner, and bag.\nADJUSTABLE ACTION: Built-in truss rod can balance the tension caused by strings or temperature change shrinking, for a straight and durable neck. The adjustable black acoustic electric guitar neck allows your hand to stay in a comfortable position by keeping the strings at a perfect height. Frontier series electric acoustic guitars have a built-in preamp for amplified use with volume control, 4 band EQ, bass, mid, treble, and press for fast and easy tuning. Perfect for juniors and adults.\nDURABLE STRINGS: Built for great sound quality, high durability, and increased ease of use. The surface is coated with a bronze coating which does not rust easily and prolongs the use of the strings. The tuning pegs are engineered for good sound quality. The tuning keys are smooth and easy to adjust to keep the guitar in tune. Kadence guitars have better bass, volume, and fuller sound. Great for all styles of music, and guitarists over 14 years old, especially beginners, students, or pros.\nEASY CUTAWAY DESIGN TO PLAY: The cutaway design of this guitar electric acoustic allows you easier access to the upper frets. The high gloss finish, simple head design, streamlined cutaway curvature makes the head and the body integrated, beautiful. The Indian rosewood bridge has high hardness, strong vibration conductivity, stable and rich tone transmission. Place the included pickguard underneath the guitar soundhole to protect from pick scratches while playing. The strings are soft to touch.\nQUALITY INSTRUMENTS FOR EVERYDAY: With a wide variety of musical instruments, Kadence is committed to developing better comfortable and functional acoustic guitars, providing quality services and excellent products. With quality instruments from Kadence, you’ll have a constant companion for life. Regardless of what you love to play, just make sure to express yourself. Whatever your age or skill level, our semi acoustic guitar will make sure all your musical desires are fulfilled.',
#  'Great looks with an innovative design to produce quality warm bright resonant tone\nMaterial: Conditioned wooden Body with Rosewood finger board, Ebony fretboard and 38-inch cutaway design\nCombo includes Premium White colored Guitar, quality and durable carry bag with extra pockets and comfort handle, Intern Plectrums, Strings and Guitar strap\nMaximum wood construction with geared tuning, pine-wood bracing, wood frame and steel strings\nSturdy box package with multiple plies plus instrument wrap ensure that guitar reaches you as it is just out of the factory with no damages or scratches\nBag with stylish nylon made and long lasting material',
#  'Black Glossy Finish, Number of Frets: 18, Acoustic Guitar with strap, Bag, Strings and 2 Picks\nGreat looks with an innovative design to produce good quality sound\nFinger board: Linden Wood, Fretboard - Ebony Wood, Size: 38 inches, Cutaway\nIncluded components: Acoustic Guitar with strap, Bag, Strings and 2 Picks\nLinden Binding and Full Wood Construction with Geared Tuning, Wood Frame and Steel Strings',
#  'Steel strung full scale neck\nSlim line contoured body for comfortable playability and a rich tone\nIncludes sturdy guitar stand\nAlso includes tuner, gig bag, strap, picks and strings\nFree online lessons\nCountry of Origin: China',
#  'Type - Acoustic Guitar with cutaway. Specially made for India. Designed in Japan and the best guitar for beginners. It comes specially checked by experts.\nFingerboard material - rosewood. Extremely comfortable guitar. Teachers all over India recommend this guitar. It is comparable with all the leading brands in the world.\nTop - Spruce. Seasoned Spruce wood is used on the top, back and sides of the guitar. These woods are sourced thoughtfully making it one of the leading acoustic guitars.\nNumber of frets - 20. The fretboard is smooth making it easy to play the guitar. The cutaway option provides easy access to the higher frets when necessary.\nNumber of strings - 6. The guitar is easy to tune due to the high quality tuning pegs used. The bridge and the overall construction is extremely well done. You will be very happy with this guitar.',
#  'Acoustic Guitar 38 inches Carbon fibre Acoustic 6 steel string Folk Guitar with higher natural tone resonance and durability. Durable and long lasting with Carry bag, strings, picks & strap. For all age-groups starting 7 years and levels of skill from beginner to semi-professionals\nGreat looks with an innovative design to produce quality sound\nEmploying the machine binding and fine handcrafting production techniques with commitment to environment using harmless and nature binding colours. High quality excellent glossy finish.\nSpecially crafted fretboard for smooth finger movement lasting at least 10 times longer than the Chinese linden wood. 5 ply box packaging for avoiding any damage to the instrument in transit\nBag with stylish nylon made and long lasting material\nPerfect combination of fibre, machine heads, strings, frets and other components for vibrant outstanding sound quality. Selected Configuration mPerfect combination of fibre, machine heads, strings, frets and other components for vibrant outstanding sound quality. Selected Configuration meant for advanced learners and performers.eant for advanced learners and performers.\nLinden binding and full wood construction with geared tuning, wood frame and steel strings',
#  'Solid agathis body\nMaple neck, Body Finish: Gloss Polyurethane\nRosewood fingerboard\nOne humbucker/2 single-coil pickups',
#  "4-string Guitar Toy for Kids with Adjustable Tuning Knobs for Intellectual Development and also to develop talent and interest in kids.\nThis guitar has good sound quality & good wooden finishing.It is made up of good quality plastic & is good for playing and learning.\nProvides screen free fun: A junior scale 4 string guitar perfect for use on lessons, recitals, band rehearsals, on-stage performances or when practicing at home. The mini guitar can attract the interests of kids, and reduce their dependency on the phone, computer, or other electronics.\nGreat for beginners: It has a traditional classic body style great for beginners and children learning to play guitar. Give your best performance whether you're in the music studio or out at a bonfire with friends. Take your music with you.\nThis Acoustic Guitar makes a great gift for kids. Lightweight, easy to hold, and has a nice appearance.This is not a professionally manufactured Guitar, just a toy for Children.",
#  'Material: Top: Spruce, Side & Back: - linden wood, Fingerboard:- Engineered Wood\nBridge：Engineered Wood, Neck: Okoume wood, Machine head: Chrome die cast, Binding: ABS, Finish- High Glossy\nIncludes: 40", acoustic guitar with Belt, bag, string set and 2 picks With TRUSS ROD adjustment support\nTruss Rod for better adjustment of Guitar Action , Size 40" ,Style - Cutway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect',
#  'Has 39-inch Cut-A-Way Guitar, Cream Binding Top and Head\nMaterial : Rosewood fingerboard and Bridge, Toon Wood Body and Neck, Pine Wood Top\nColour : Wine Red in High Gloss Finish, Chrome Keys\nPackage Content : 1 Guitar, Guitar Cover/Bag, Strings Pack, String winder and 5 Plectrums',
#  'Material: Top: Spruce, Side & Back: - Bass wood, Fingerboard:- Rosewood\nBridge：Rosewood, Neck: Okoume wood, Machine head: Chrome die cast, Binding: ABS, Finish- Satin\nIncludes: 40 Inch Acoustic guitar with Belt, bag, string set and 2 picks With TRUSS ROD adjustment support\nTruss Rod for better adjustment of Guitar Action , Size 40" ,Style - Cutaway, innovative design to produce good quality sound\nNote: Product design may slightly vary Due to Photography lighting effect']

# %%
# Creating the DataFrame for the scraped data

Product = pd.DataFrame({})
Product["Brand Name"] = BrandName
Product["Product Name"] = Product_Name
Product["Price"] = Price
Product["Expected Delivery"] = Expected_delivery
Product["Availability"] = Availability
Product["Other Details"] = Other_Details
Product["Product URL"] = urls
Product.head()
# Out:
#                   Brand Name  \
# 0    Visit the Kadence Store
# 1    Visit the Kadence Store
# 2  Visit the blueberry Store
# 3  Visit the blueberry Store
# 4     Visit the JUAREZ Store
#
#                                         Product Name      Price  \
# 0  Kadence Frontier guitar with Online Guitar lea...  ₹5,399.00
# 1  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...  ₹7,348.00
# 2  Blueberry 38C, 38" Acoustic Guitar Kit with Ba...  ₹2,560.00
# 3  Blueberry B-D38 Sunburst 38 Inch Acoustic Guit...          -
# 4  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...          -
#
#   Expected Delivery Availability  \
# 0                 -
# 1                 -    In stock.
# 2                 -            -
# 3                 -    In stock.
# 4                 -    In stock.
#
#                                        Other Details  \
# 0  ★ Design - The High Gloss finish, Simple head ...
# 1  QUALITY STRINGS ---The surface is coated with ...
# 2  Material: Top: linden wood, Side & Back: - lin...
# 3  Material: Top: linden wood, Side & Back: - lin...
# 4  Black Glossy Finish, Number of Frets: 18, Acou...
#
#                                          Product URL
# 0  https://www.amazon.in/gp/slredirect/picassoRed...
# 1  https://www.amazon.in/gp/slredirect/picassoRed...
# 2  https://www.amazon.in/gp/slredirect/picassoRed...
# 3  https://www.amazon.in/gp/slredirect/picassoRed...
# 4  https://www.amazon.in/Juarez-Acoustic-Cutaway-...

# %% [markdown]
# Q3: Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
url3 = 'http://www.images.google.com'  #opening the website
driver.get(url3)
time.sleep(3)
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    #Accessing the search bar
search_bar.send_keys(input())                                                #Used input fuction so that used could give unique keyword everyytime
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')  #Accessing the search button
search_btn.click()
# Out:
# Fruits

# %%
for i in range(2000):
    driver.execute_script("window.scrollBy(0,10000)")                       #Scrolling the windows of the search page.
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []                                                               #Empty list
for image in images: 
    source = image.get_attribute('src')                                    #Source of the image's
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)                                                              
for i in range(len(img_urls)):                                             #Here we have used range fuc. and inside that we have given len fuc.(due to this our code will run the same no. of time as the lenth of img.)
    if i>10:                                                               #We want to download 10 images.
        break
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Surjit Singh Kadian\Downloads\New folder"+str(i)+".jpg","wb")   #Opeing the folder location where we want to download
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
# Used the same code but the only difference is here I have changed the keyword from fruits to Cars.
url3 = 'http://www.images.google.com'  #opening the website
driver.get(url3)
time.sleep(3)
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    #Accessing the search bar
search_bar.send_keys(input())                                                #Used input fuction so that used could give unique keyword everyytime
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')  #Accessing the search button
search_btn.click()


for i in range(2000):
    driver.execute_script("window.scrollBy(0,10000)")                       #Scrolling the windows of the search page.
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []                                                               #Empty list
for image in images: 
    source = image.get_attribute('src')                                    #Source of the image's
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)                                                              
for i in range(len(img_urls)):                                             #Here we have used range fuc. and inside that we have given len fuc.(due to this our code will run the same no. of time as the lenth of img.)
    if i>10:                                                               #We want to download 10 images.
        break
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Surjit Singh Kadian\Downloads\New folder"+str(i)+".jpg","wb")   #Opeing the folder location where we want to download
    file.write(response.content)
# Out:
# Cars
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
# Used the same code but the only difference is here I have changed the keyword from Cars to Machine Learning.

url3 = 'http://www.images.google.com'  #opening the website
driver.get(url3)
time.sleep(3)
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    #Accessing the search bar
search_bar.send_keys(input())                                                #Used input fuction so that used could give unique keyword everyytime
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')  #Accessing the search button
search_btn.click()


for i in range(2000):
    driver.execute_script("window.scrollBy(0,10000)")                       #Scrolling the windows of the search page.
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []                                                               #Empty list
for image in images: 
    source = image.get_attribute('src')                                    #Source of the image's
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)                                                              
for i in range(len(img_urls)):                                             #Here we have used range fuc. and inside that we have given len fuc.(due to this our code will run the same no. of time as the lenth of img.)
    if i>10:                                                               #We want to download 10 images.
        break
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Surjit Singh Kadian\Downloads\New folder"+str(i)+".jpg","wb")   #Opeing the folder location where we want to download
    file.write(response.content)
# Out:
# Machine Learning
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
# Used the same code but the only difference is here I have changed the keyword from Machine Learning to Guitar.

url3 = 'http://www.images.google.com'  #opening the website
driver.get(url3)
time.sleep(3)
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    #Accessing the search bar
search_bar.send_keys(input())                                                #Used input fuction so that used could give unique keyword everyytime
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')  #Accessing the search button
search_btn.click()


for i in range(2000):
    driver.execute_script("window.scrollBy(0,10000)")                       #Scrolling the windows of the search page.
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []                                                               #Empty list
for image in images: 
    source = image.get_attribute('src')                                    #Source of the image's
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)                                                              
for i in range(len(img_urls)):                                             #Here we have used range fuc. and inside that we have given len fuc.(due to this our code will run the same no. of time as the lenth of img.)
    if i>10:                                                               #We want to download 10 images.
        break
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Surjit Singh Kadian\Downloads\New folder"+str(i)+".jpg","wb")   #Opeing the folder location where we want to download
    file.write(response.content)
# Out:
# Guitar
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
# Used the same code but the only difference is here I have changed the keyword from Guitar to Cakes.

url3 = 'http://www.images.google.com'  #opening the website
driver.get(url3)
time.sleep(3)
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    #Accessing the search bar
search_bar.send_keys(input())                                                #Used input fuction so that used could give unique keyword everyytime
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')  #Accessing the search button
search_btn.click()


for i in range(2000):
    driver.execute_script("window.scrollBy(0,10000)")                       #Scrolling the windows of the search page.
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []                                                               #Empty list
for image in images: 
    source = image.get_attribute('src')                                    #Source of the image's
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)                                                              
for i in range(len(img_urls)):                                             #Here we have used range fuc. and inside that we have given len fuc.(due to this our code will run the same no. of time as the lenth of img.)
    if i>10:                                                               #We want to download 10 images.
        break
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(img_urls[i])
    file = open(r"C:\Users\Surjit Singh Kadian\Downloads\New folder"+str(i)+".jpg","wb")   #Opeing the folder location where we want to download
    file.write(response.content)
# Out:
# Cakes
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %% [markdown]
# Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
url = 'https://www.flipkart.com/'
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
# Closing Login popup button
loginbtn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()

# %%
# Searching for web element
search_bar = driver.find_element_by_xpath("//input[@class='_3704LK']")
# Sending keys to search product
search_bar.send_keys("pixel 4A")

# %%
# Locating the search button using xpath
search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
# Clicking on search button
search_btn.click()

# %%
# Fetching 1st page URLs of smartphone
page1_url = []   #empty list
urls = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for url in urls:
    page1_url.append(url.get_attribute('href'))

# %%
len(page1_url)
# Out:
# 24

# %%
page1_url
# Out:
# ['https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WU0WEW8&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVKYHCVG7W.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHYFKQP8K&lid=LSTMOBGDRHVHYFKQP8KYHDDNN&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVHYFKQP8K.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHV86NZHMDM&lid=LSTMOBGDRHV86NZHMDMR0BLSS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHV86NZHMDM.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVWJUFTYQJ&lid=LSTMOBGDRHVWJUFTYQJ7NGITG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVWJUFTYQJ.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJMHFQJFCX3&lid=LSTMOBG7CJMHFQJFCX3ITLYP2&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7CJMHFQJFCX3.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7H8GFGZPYUFH&lid=LSTMOBG7H8GFGZPYUFHNDH4SS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7H8GFGZPYUFH.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CHHZ2MUWAZ4&lid=LSTMOBG7CHHZ2MUWAZ447JNIX&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7CHHZ2MUWAZ4.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HN5VTU6RR.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-10-prime-phantom-black-128-gb/p/itm9377b4c936baa?pid=MOBG6RGPPXQFYJ4R&lid=LSTMOBG6RGPPXQFYJ4ROU633K&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG6RGPPXQFYJ4R.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7DGGNP5N2RXH&lid=LSTMOBG7DGGNP5N2RXHPHGAZG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7DGGNP5N2RXH.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-pro-5g-turbo-black-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHV9AZEZTN7&lid=LSTMOBGDRHV9AZEZTN7WV8UBJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHV9AZEZTN7.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-t1-pro-5g-turbo-cyan-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHVRHDZCJ4Q&lid=LSTMOBGDRHVRHDZCJ4QOKUEEL&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVRHDZCJ4Q.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-y21g-diamond-glow-64-gb/p/itmcb4986f752d3d?pid=MOBGD6DGKVFJJN6N&lid=LSTMOBGD6DGKVFJJN6NWODOCM&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGD6DGKVFJJN6N.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/vivo-y21g-midnight-blue-64-gb/p/itmcb4986f752d3d?pid=MOBGD6DG7HXHP4KP&lid=LSTMOBGD6DG7HXHP4KPDTSFLP&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGD6DG7HXHP4KP.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HQJZKSX3K.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-10a-charcoal-black-32-gb/p/itm755830dd54ae1?pid=MOBGDRGHYWAAZDVD&lid=LSTMOBGDRGHYWAAZDVDRZXZKV&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRGHYWAAZDVD.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-10-prime-astral-white-128-gb/p/itm9377b4c936baa?pid=MOBG6RGJGTKTUVD9&lid=LSTMOBG6RGJGTKTUVD9SIJJKG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG6RGJGTKTUVD9.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/redmi-note-11-horizon-blue-64-gb/p/itm2a388ca843b21?pid=MOBGBGAETVKA2NEZ&lid=LSTMOBGBGAETVKA2NEZ1YAFLX&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGBGAETVKA2NEZ.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d']

# %%
Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary Camera"] = []
Smartphones["Secondary Camera"] = []
Smartphones["Display Size"] = []
Smartphones["Display Resolution"] = []
Smartphones["Processor"] = []
Smartphones["Processor Cores"] = []
Smartphones["Battery Capacity"] = []
Smartphones["Price"] = []
Smartphones["URL"] = []

# %%
# Scraping data from each url of page 1
for url in page1_url:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button to get more information
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    
    
    #Scraping brand name of smartphone
    try:
        brand_tags = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      
        Smartphones["Brand"].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    #Scraping name of smartphone
    try:
        name_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')     
        Smartphones['Phone name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone name'].append('-')
    
    
    #Scraping colour of smartphone
    try:
        color_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
     
    
    #Scraping RAM data of smartphone
    try:
        ram_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data of smartphone
    try:
        rom_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
        Smartphones['Storage(ROM)'].append(rom_tags.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
        
    #Scraping Primary camera data of smartphone
    try:                                                                                    
        pri_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Smartphones['Primary Camera'].append(pri_tags.text)
    except NoSuchElementException:
        Smartphones['Primary Camera'].append('-')
        
        
    #Scraping secondary camera data of smarphone
    try:                                                                                    
        sec_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if sec_tags != "Secondary Camera" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        Smartphones['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        Smartphones['Secondary Camera'].append('-')
        
        
    #Scraping Display size data of smartpone
    try:
        disp_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if disp_tags.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
        Smartphones['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display Size'].append('-')
    
    
    #Scraping display resolution of smartphone
    try:
        dires_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if dires_tags.text != "Display Features" : raise NoSuchElementException
        disp_reso = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[2]/td[2]/ul/li')    
        Smartphones['Display Resolution'].append(disp_reso.text)
    except NoSuchElementException:
        Smartphones['Display Resolution'].append('-')
    
    
    
    #Scraping Processor of smartphone
    try:
        pro_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
        if pro_tags.text != "Processor Type" : raise NoSuchElementException
        processor = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')   
        Smartphones['Processor'].append(processor.text)
    except NoSuchElementException:
        Smartphones['Processor'].append('-')
        
    
    
    #Scraping Processor core of smartphone 
    try:                                                                                     
        core_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[1]')
        if core_tags.text != "Processor Core" :
            core_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
            if core_tags.text != "Processor Core" : 
                raise NoSuchElementException
            else :
                cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')
        else :
            cores = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[2]/ul/li')
        Smartphones['Processor Cores'].append(cores.text)
    except NoSuchElementException:
        Smartphones['Processor Cores'].append('-')
    
    
    
    #Scraping battery capacity of smartphone
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Smartphones['Battery Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery Capacity'].append('-')
        
        
        
    #Scraping Price of smartphone
    try:
        price_tags = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      
        Smartphones['Price'].append(price_tags.text)
    except NoSuchElementException:
        Smartphones['Price'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WU0WEW8&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVKYHCVG7W.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHYFKQP8K&lid=LSTMOBGDRHVHYFKQP8KYHDDNN&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVHYFKQP8K.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHV86NZHMDM&lid=LSTMOBGDRHV86NZHMDMR0BLSS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHV86NZHMDM.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVWJUFTYQJ&lid=LSTMOBGDRHVWJUFTYQJ7NGITG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVWJUFTYQJ.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJMHFQJFCX3&lid=LSTMOBG7CJMHFQJFCX3ITLYP2&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7CJMHFQJFCX3.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7H8GFGZPYUFH&lid=LSTMOBG7H8GFGZPYUFHNDH4SS&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7H8GFGZPYUFH.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CHHZ2MUWAZ4&lid=LSTMOBG7CHHZ2MUWAZ447JNIX&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7CHHZ2MUWAZ4.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HN5VTU6RR.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-phantom-black-128-gb/p/itm9377b4c936baa?pid=MOBG6RGPPXQFYJ4R&lid=LSTMOBG6RGPPXQFYJ4ROU633K&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG6RGPPXQFYJ4R.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7DGGNP5N2RXH&lid=LSTMOBG7DGGNP5N2RXHPHGAZG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG7DGGNP5N2RXH.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-black-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHV9AZEZTN7&lid=LSTMOBGDRHV9AZEZTN7WV8UBJ&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHV9AZEZTN7.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-pro-5g-turbo-cyan-128-gb/p/itmdbb5d58c3018d?pid=MOBGDRHVRHDZCJ4Q&lid=LSTMOBGDRHVRHDZCJ4QOKUEEL&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRHVRHDZCJ4Q.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-y21g-diamond-glow-64-gb/p/itmcb4986f752d3d?pid=MOBGD6DGKVFJJN6N&lid=LSTMOBGD6DGKVFJJN6NWODOCM&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGD6DGKVFJJN6N.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-y21g-midnight-blue-64-gb/p/itmcb4986f752d3d?pid=MOBGD6DG7HXHP4KP&lid=LSTMOBGD6DG7HXHP4KPDTSFLP&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGD6DG7HXHP4KP.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDC6HQJZKSX3K.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10a-charcoal-black-32-gb/p/itm755830dd54ae1?pid=MOBGDRGHYWAAZDVD&lid=LSTMOBGDRGHYWAAZDVDRZXZKV&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGDRGHYWAAZDVD.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-astral-white-128-gb/p/itm9377b4c936baa?pid=MOBG6RGJGTKTUVD9&lid=LSTMOBG6RGJGTKTUVD9SIJJKG&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBG6RGJGTKTUVD9.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-note-11-horizon-blue-64-gb/p/itm2a388ca843b21?pid=MOBGBGAETVKA2NEZ&lid=LSTMOBGBGAETVKA2NEZ1YAFLX&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=11c27d3c-d508-4613-aac5-94b9d0dc6cbc.MOBGBGAETVKA2NEZ.SEARCH&ppt=hp&ppn=homepage&ssid=ya8p212nz40000001654252660624&qH=9b26a23b2cff510d

# %%
#Checking lengths of all scraped data
print(len(Smartphones["Brand"]), len(Smartphones["Phone name"]), len(Smartphones["Colour"]), len(Smartphones["RAM"]), len(Smartphones["Storage(ROM)"]), len(Smartphones["Primary Camera"]), len(Smartphones["Secondary Camera"]), len(Smartphones["Display Size"]), len(Smartphones["Display Resolution"]), len(Smartphones["Processor"]), len(Smartphones["Processor Cores"]), len(Smartphones["Battery Capacity"]), len(Smartphones["Price"]), len(Smartphones['URL']))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24 24 24 24

# %%
df = pd.DataFrame.from_dict(Smartphones)
df
# Out:
#       Brand      Phone name           Colour   RAM Storage(ROM)  \
# 0    Google        Pixel 4a       Just Black  6 GB       128 GB
# 1      vivo          T1 44W         Ice Dawn  4 GB       128 GB
# 2      vivo          T1 44W       Starry Sky  4 GB       128 GB
# 3      vivo          T1 44W       Starry Sky  6 GB       128 GB
# 4      vivo          T1 44W  Midnight Galaxy  4 GB       128 GB
# 5      vivo          T1 44W       Starry Sky  8 GB       128 GB
# 6      vivo          T1 44W  Midnight Galaxy  6 GB       128 GB
# 7      vivo          T1 44W         Ice Dawn  8 GB       128 GB
# 8      vivo          T1 44W  Midnight Galaxy  8 GB       128 GB
# 9     Redmi  Redmi 9A Sport     Carbon Black  3 GB        32 GB
# 10    Redmi  Redmi 9A Sport    Metallic Blue  3 GB        32 GB
# 11    Redmi  Redmi 9A Sport      Coral Green  2 GB        32 GB
# 12  Infinix         Smart 6    Starry Purple  2 GB        64 GB
# 13  Infinix         Smart 6   Heart Of Ocean  2 GB        64 GB
# 14    REDMI        10 Prime    Phantom Black  6 GB       128 GB
# 15    Redmi  Redmi 9A Sport     Carbon Black  2 GB        32 GB
# 16     vivo       T1 Pro 5G      Turbo Black  8 GB       128 GB
# 17     vivo       T1 Pro 5G       Turbo Cyan  8 GB       128 GB
# 18     vivo            Y21G     Diamond Glow  4 GB        64 GB
# 19     vivo            Y21G    Midnight Blue  4 GB        64 GB
# 20  Infinix         Smart 6  Light Sea Green  2 GB        64 GB
# 21    REDMI       REDMI 10A   Charcoal Black  3 GB        32 GB
# 22    REDMI        10 Prime     Astral White  6 GB       128 GB
# 23    Redmi   Redmi Note 11     Horizon Blue  4 GB        64 GB
#
#             Primary Camera   Secondary Camera          Display Size  \
# 0       12.2MP Rear Camera   8MP Front Camera  14.76 cm (5.81 inch)
# 1         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 2         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 3         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 4         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 5         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 6         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 7         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 8         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 9         13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 10        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 11        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 12       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 13       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 14  50MP + 8MP + 2MP + 2MP   8MP Front Camera   16.51 cm (6.5 inch)
# 15        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 16        64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 17        64MP + 8MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 18              13MP + 2MP   8MP Front Camera  16.54 cm (6.51 inch)
# 19              13MP + 2MP   8MP Front Camera  16.54 cm (6.51 inch)
# 20       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 21          Primary Camera                  -  16.59 cm (6.53 inch)
# 22  50MP + 8MP + 2MP + 2MP   8MP Front Camera   16.51 cm (6.5 inch)
# 23  50MP + 8MP + 2MP + 2MP  13MP Front Camera  16.33 cm (6.43 inch)
#
#     Display Resolution                                    Processor  \
# 0   2340 x 1080 Pixels                     Qualcomm Snapdragon 730G
# 1    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 2    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 3    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 4    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 5    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 6    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 7    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 8    2400 x 1080 Pixel                      Qualcomm Snapdragon 680
# 9    1600 x 720$$pixel                           MediaTek Helio G25
# 10   1600 x 720$$pixel                           MediaTek Helio G25
# 11   720 x 1600$$pixel                           MediaTek Helio G25
# 12    1600 x 720 Pixel                           Mediatek Helio A22
# 13    1600 x 720 Pixel                           Mediatek Helio A22
# 14  2400 x 1080$$Pixel                                    Helio G88
# 15   720 x 1600$$pixel                           MediaTek Helio G25
# 16   2404 x 1080 Pixel  Qualcomm Snapdragon 778G 5G Mobile Platform
# 17   2404 x 1080 Pixel  Qualcomm Snapdragon 778G 5G Mobile Platform
# 18    1600 x 720 Pixel                    Mediatek MT6769 Helio G70
# 19    1600 x 720 Pixel                    Mediatek MT6769 Helio G70
# 20    1600 x 720 Pixel                           Mediatek Helio A22
# 21   1600 x 700$$pixel                                            -
# 22  2400 x 1080$$Pixel                                    Helio G88
# 23  2400 x 1080$$pixel               Qualcomm SM6225 Snapdragon 680
#
#    Processor Cores Battery Capacity    Price  \
# 0        Octa Core         3140 mAh  ₹31,999
# 1        Octa Core         5000 mAh  ₹14,499
# 2        Octa Core         5000 mAh  ₹14,499
# 3        Octa Core         5000 mAh  ₹15,999
# 4        Octa Core         5000 mAh  ₹14,499
# 5        Octa Core         5000 mAh  ₹17,999
# 6        Octa Core         5000 mAh  ₹15,999
# 7        Octa Core         5000 mAh  ₹17,999
# 8        Octa Core         5000 mAh  ₹17,999
# 9        Octa Core         5000 mAh   ₹7,919
# 10       Octa Core         5000 mAh   ₹8,300
# 11       Octa Core         5000 mAh   ₹6,887
# 12       Quad Core         5000 mAh   ₹7,499
# 13       Quad Core         5000 mAh   ₹7,499
# 14       Octa Core         6000 mAh  ₹14,295
# 15       Octa Core         5000 mAh   ₹6,874
# 16       Octa Core         4700 mAh  ₹24,999
# 17       Octa Core         4700 mAh  ₹24,999
# 18       Octa Core         5000 mAh  ₹13,499
# 19       Octa Core         5000 mAh  ₹13,499
# 20       Quad Core         5000 mAh   ₹7,499
# 21       Octa Core                -   ₹8,900
# 22       Octa Core         6000 mAh  ₹14,198
# 23       Octa Core         5000 mAh  ₹12,999
#
#                                                   URL
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 2   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 3   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 4   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 5   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 6   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 7   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 8   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 9   https://www.flipkart.com/redmi-9a-sport-carbon...
# 10  https://www.flipkart.com/redmi-9a-sport-metall...
# 11  https://www.flipkart.com/redmi-9a-sport-coral-...
# 12  https://www.flipkart.com/infinix-smart-6-starr...
# 13  https://www.flipkart.com/infinix-smart-6-heart...
# 14  https://www.flipkart.com/redmi-10-prime-phanto...
# 15  https://www.flipkart.com/redmi-9a-sport-carbon...
# 16  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 17  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 18  https://www.flipkart.com/vivo-y21g-diamond-glo...
# 19  https://www.flipkart.com/vivo-y21g-midnight-bl...
# 20  https://www.flipkart.com/infinix-smart-6-light...
# 21  https://www.flipkart.com/redmi-10a-charcoal-bl...
# 22  https://www.flipkart.com/redmi-10-prime-astral...
# 23  https://www.flipkart.com/redmi-note-11-horizon...

# %%
# Saving data in csv
df.to_csv("Smartphone.csv")

# %% [markdown]
# Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# Getting mentioned url and opening google maps web page
url = "https://www.google.co.in/maps"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
# entering the city name in search bar 
City = input('Enter City name that has to be searched : ')
search_bar = driver.find_element_by_id("searchboxinput")                       
search_bar.clear()                                                             
time.sleep(2)
# Out:
# Enter City name that has to be searched : Navi Mumbai, Maharashtra

# %%
# Sending keys to find cities
search_bar.send_keys(City) 

# Checking for webelement and Clicking on search button
search_btn = driver.find_element_by_id("searchboxinput")              
search_btn.click()                                                             
time.sleep(2)

# %%
try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Mumbai,+Maharashtra/@19.0820391,72.6009752,10z/data=!3m1!4b1!4m5!3m4!1s0x3be7c6306644edc1:0x5da4ed8f8d648c69!8m2!3d19.0759837!4d72.8776559
# Latitude = 19.0820391, Longitude = 72.6009752

# %% [markdown]
# Q6: Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# opening the url track.in
url = "https://trak.in/"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
#Getting xpath for funding deals and clicking on the button
fundbutton = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(fundbutton)

# %%
# Empty lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry/Vertical'] = []
fund_deals['Sub-Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []

# %%
for i in range(48,51):

    # Scraping data of Date
    date = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in date:
        fund_deals['Date'].append(d.text)

    # Scraping data of Startup Name
    startup_name= driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for name in startup_name:
        fund_deals['Startup Name'].append(name.text)
    
    # Scraping data of Industry OR Vertical
    industry = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for ind in industry:
        fund_deals['Industry/Vertical'].append(ind.text)
    
    # Scraping data of Sub-Vertical
    sub_vertical = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for sv in sub_vertical:
        fund_deals['Sub-Vertical'].append(sv.text)

    # Scraping data of Location
    location = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for loc in location:
        fund_deals['Location'].append(loc.text)
    
    # Scraping data of Investor
    investor = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for invest in investor:
        fund_deals['Investor'].append(invest.text)
        
    # Scraping data of Investment Type
    investment_type = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for invtype in investment_type:
        fund_deals['Investment Type'].append(invtype.text)
        
    #  data of Amount
    amount = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for amt in amount:
        fund_deals['Amount(in USD)'].append(amt.text)

# %%
# DataFrame for scraped data
fund_details = pd.DataFrame(fund_deals)
fund_details
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %%
#Saving data in csv file
fund_details.to_csv("Trak_in.csv")

# %% [markdown]
# Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# opening the url digit.in
url = "https://www.digit.in/"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
#searching for best laptop
best_gam_laptops = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# %%
#Creating empty lists
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Price = []

# %%
# Scraping the data of laptop names
laptop_name= driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memory = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass


#Scraping data of weight
try:
    weight = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass


#Scraping data of dimensions
try:
    dimension = driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass



#Scraping data of price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),len(Operating_sys),len(Display),len(Processor),len(Memory),len(Weight),len(Dimensions),len(Price))
# Out:
# 10 10 10 10 10 10 10 10

# %%
#  DataFrame for scraped data
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating system'] = Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Weight'] = Weight
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                    Laptop Name    Operating system  \
# 0              MSI RAIDER GE76  WINDOWS 11 HOME OS
# 1       ASUS ROG STRIX SCAR 15  WINDOWS 11 HOME OS
# 2                 ACER NITRO 5       WINDOWS 10 OS
# 3              MSI STEALTH 15M       WINDOWS 10 OS
# 4       ASUS ROG STRIX SCAR 15       WINDOWS 10 OS
# 5       ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME OS
# 6            ASUS ZEPHYRUS G14  WINDOWS 10 HOME OS
# 7                   HP OMEN 16  WINDOWS 11 HOME OS
# 8     ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10 OS
# 9  ACER ASPIRE 7 GAMING LAPTOP  WINDOWS 10 HOME OS
#
#                        Display        Processor  \
# 0    17" (3840 X 2160) DISPLAY  Windows 11 Home
# 1  15.6" (2560 X 1440) DISPLAY  Windows 11 Home
# 2  15.6" (1920 X 1080) DISPLAY       Windows 10
# 3  15.6" (1920 X 1080) DISPLAY       Windows 10
# 4  15.6" (2560 X 1440) DISPLAY       Windows 10
# 5  15.6" (1920 X 1080) DISPLAY  Windows 10 Home
# 6    14" (1920 X 1080) DISPLAY  Windows 10 Home
# 7  16.1" (1920 X 1080) DISPLAY  Windows 11 Home
# 8  15.6" (3840 X 1100) DISPLAY       Windows 10
# 9  15.6" (1920 X 1080) DISPLAY  Windows 10 Home
#
#                                       Memory  \
# 0                  16 GB DDR5 RAM & 2 TB SSD
# 1                  32 GB DDR5 RAM & 2 TB SSD
# 2  16 GB DDR4 RAM & 1 TB HDD with 256 GB SSD
# 3                  16 GB DDR4 RAM & 1 TB SSD
# 4                  32 GB DDR4 RAM & 2 TB SSD
# 5                  16 GB DDR4 RAM & 1 TB SSD
# 6                  16 GB DDR4 RAM & 1 TB SSD
# 7                  16 GB DDR4 RAM & 1 TB SSD
# 8                 4 GB DDR4 RAM & 512 GB SSD
# 9                 8 GB DDR4 RAM & 512 GB SSD
#
#                                               Weight  \
# 0            NVIDIA GeForce RTX 3080Ti Graphics card
# 1  8 GB DDR6 NVIDIA GeForce RTX 3070 Ti Graphics ...
# 2              NVIDIA GeForce RTX 3070 Graphics card
# 3              NVIDIA GeForce RTX 3060 Graphics card
# 4              NVIDIA GeForce RTX 3080 Graphics card
# 5            NVIDIA® GeForce RTX™ 3070 Graphics card
# 6              NVIDIA GeForce RTX 2060 Graphics card
# 7   6 GB GDDR6 NVIDIA GeForce RTX 3060 Graphics card
# 8        NVIDIA GeForce RTX 2070 Max-Q Graphics card
# 9            NVIDIA® GeForce® GTX 1650 Graphics card
#
#                                           Dimensions        Price
# 0        397 x 284 x 26 mm dimension & 2.9 kg weight  Rs  429,940
# 1        259 x 354 x 27 mm dimension & 2.3 kg weight  Rs  274,990
# 2    363.4 x 255 x 23.9 mm dimension & 2.4 kg weight  Rs  129,990
# 3   358.3 x 248 x 16.15 mm dimension & 1.7 kg weight  Rs  134,990
# 4     354 x 259 x 22.6 mm dimension & 2.30 kg weight  Rs  193,990
# 5   35.4 x 25.9 x 2.26 mm dimension & 2.30 kg weight  Rs  215,990
# 6    32.5 x 22.1 x 1.8 mm dimension & 1.65 kg weight  Rs  144,990
# 7   36.92 x 24.8 x 2.3 mm dimension & 2.32 kg weight  Rs  136,990
# 8  268.30 x 360.00 x 20.90 mm dimension & 2.4 kg ...  Rs  185,000
# 9   2.29 x 36.3 x 25.4 mm dimension & 2.15 kg weight   Rs  53,490

# %%
#Saving dataset to csv
Gaming_Laptop.to_csv("GamingLaptops.csv")

# %% [markdown]
# Q8: Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
#Getting the specified url
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
#clicking on the explore button
button = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button.click()
time.sleep(1)

# %%
#select billionaire  
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)

# %%
#select world billionaire  
world_bill= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)

# %%
#Scraping required data from the web page
#Creating empty lists
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []


while(True):
    #Scraping the data of rank of the billionaires
    rank_tags= driver.find_elements_by_xpath("//div[@class='rank']")
    for rank in rank_tags:
        Rank.append(rank.text)
    time.sleep(1)
    
    
    #Scraping the data of names of the billionaires
    name_tags= driver.find_elements_by_xpath("//div[@class='personName']/div")
    for name in name_tags:
        Person_Name.append(name.text)
    time.sleep(1)
    
    
    #Scraping data of age of the billionaires
    age_tags= driver.find_elements_by_xpath("//div[@class='age']/div")
    for age in age_tags:
        Age.append(age.text)   
    time.sleep(1)
    
    
    #Scraping data of citizenship of the billionaires
    cit_tags= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for cit in cit_tags:
        citizenship.append(cit.text)
    time.sleep(1)
    
    
    #Scraping data of source of income of the billionaires
    sour_tags= driver.find_elements_by_xpath("//div[@class='source']")
    for sour in sour_tags:
        Source.append(sour.text)    
    time.sleep(1)
    
    
    #Scraping data of Industry of the billionaires
    ind_tags= driver.find_elements_by_xpath("//div[@class='category']//div")
    for ind in ind_tags:
        industry.append(ind.text)
        
        
    #scraping data of net_worth of billionaires
    net_tags= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
    for net in net_tags:
        total_net_worth.append(net.text)
    time.sleep(1)
    
    
    #Clicking on next button
    try:
        next_button = driver.find_element_by_xpath("//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break
        
#Scraping data of net worth
Net_Worth = []
for i in range(0,len(total_net_worth),2):
    Net_Worth.append(total_net_worth[i])

# %%
#Framing data
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name
Billionaires['Net Worth'] = Net_Worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = industry
Billionaires
# Out:
#        Rank                    Names Net Worth Age    Citizenship  \
# 0                                       $219 B      United States
# 1                                       $171 B      United States
# 2                                       $158 B             France
# 3                                       $129 B      United States
# 4                                       $118 B      United States
# ...     ...                      ...       ...  ..            ...
# 2663  2578.            Zhang Yuqiang      $1 B  66          China
# 2664  2578.               Zhou Ruxin      $1 B  59          China
# 2665  2578.        Wen Zhou & family      $1 B  57          China
# 2666  2578.     Zhou Yifeng & family      $1 B  43          China
# 2667  2578.  Zhuang Kuilong & family      $1 B  59          China
#
#                        Source               Industry
# 0               Tesla, SpaceX             Automotive
# 1                      Amazon             Technology
# 2                        LVMH       Fashion & Retail
# 3                   Microsoft             Technology
# 4          Berkshire Hathaway  Finance & Investments
# ...                       ...                    ...
# 2663               Fiberglass          Manufacturing
# 2664               Navigation             Technology
# 2665                chemicals          Manufacturing
# 2666  liquefied petroleum gas                 Energy
# 2667                polyester          Manufacturing
#
# [2668 rows x 7 columns]

# %%
#Saving dataset in csv
Billionaires.to_csv("ForbesBillionaries.csv")

# %% [markdown]
# Q9: Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# Opening the youtube.com
url = "https://www.youtube.com/"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
search_bar = driver.find_element_by_xpath("//input[@class='ytd-searchbox']")
search_bar
search_bar.send_keys("GOT")

# %%
#Clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)

# %%
#Clicking on first video
video = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
video.click()

# %%
# 1000 time we scroll down by 1000 in order to generate more Comments
for _ in range(2000):
    driver.execute_script("window.scrollBy(0,2000)")

# %%
#Creating empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# %%
#scrape comments
cm = driver.find_elements_by_id("content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(5)


# scrape time when comment was posted
tm = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(5)
    
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
# dataframe for scraped data

Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[:500]
Youtube['Comment_time'] = comment_time[:500]
Youtube['Comment upvotes'] = No_of_Likes[:500]
Youtube
# Out:
#                                               Comments           Comment_time  \
# 0                                   History In Making           10 months ago
# 1    Not only a legend\nHe is the god of music indu...  11 hours ago (edited)
# 2    Sidhu Moose Wala ahora se a convertido en una ...             2 days ago
# 3    No one can become the G.O.A.T like him. Bhai j...             3 days ago
# 4    Can't believe this gem is no more...always lov...              1 day ago
# ..                                                 ...                    ...
# 495                    Legend never die shidu jatav 🇮🇳           10 hours ago
# 496              Long live rahu dila vich ustaad ji ️️              1 day ago
# 497               This song feelings got me goosebumps    3 days ago (edited)
# 498  May his soul rest in peace. \nLove from Afghan...             3 days ago
# 499  ਮਰ ਜਾਂਦੇ ਜੱਟ Down ਹੁੰਦੇ ਨਾ\nਸਾਡਾ ਮੁੱਢ ਤੋਂ ਹੀ ਲ...            5 hours ago
#
#     Comment upvotes
# 0               987
# 1                30
# 2                63
# 3                 6
# 4               272
# ..              ...
# 495               1
# 496
# 497
# 498
# 499              53
#
# [500 rows x 3 columns]

# %%
#Saving dataset to csv
Youtube.to_csv("YoutubeComments.csv")

# %% [markdown]
# Q10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description

# %%
# get the web driver
driver = webdriver.Chrome(r"C:\Users\Surjit Singh Kadian\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
# Getting the web page of mentioned url
url = "https://www.hostelworld.com/"
driver.get(url)

time.sleep(2)
driver.maximize_window()

# %%
#locating the location search
search= driver.find_element_by_xpath("//input[@class='search-input']")

# Entering Lonodn in search bar
search.send_keys("London")
time.sleep(3)

# %%
#Select london
London = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div")
# Clicking on the button
London.click()
time.sleep(3)

# %%
# Do click on search button
search_btn = driver.find_element_by_id('search-button')
search_btn.click()

# %%
# find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

# %%
name = []                        # Empty List
distance=[]
ratings=[]
reviews=[]
treview=[]
private=[]
dorms=[]
facilities=[]
hurl=[]

while(True):   
    nam=driver.find_elements_by_xpath('//h2[@class="title title-6"]')                # Extracting the Desired Element's by xpath
    dis=driver.find_elements_by_xpath('//div[@class="title-row"]/div/a/span[1]')
    rat=driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]')
    rev=driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]')
    tre=driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]')
    pri=driver.find_elements_by_xpath('//div[@class="price-col"]')
    dor=driver.find_elements_by_xpath('//div[@class="price-col"]')
    faci=driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    urls=driver.find_elements_by_xpath("//h2[@class='title title-6']/a")

    for i in nam:
        name.append(i.text)                    # Appending the Text Data
    for j in dis:
        distance.append(j.text)
    for k in rat:
        ratings.append(k.text.split('\n')[0])
    for l in rev:
        reviews.append(l.text.split('\n')[1])
    for m in tre:
            treview.append(m.text.split()[2])
    for o in pri:
        private.append(o.text.replace('\n',''))
    for p in dor:
        dorms.append(p.text.replace('\n',''))
    for q in faci:
        facilities.append(q.text)
    for url in urls:
        hurl.append(url.get_attribute('href'))
        
    for n in reviews:                            # As there were some data in 'OverAll Reviews' column some of the data were missing, so replacing those data by "none"
        if "Rating"in n:
            reviews[reviews.index(n)] = "None"
        elif "Reviews"in n:
            reviews[reviews.index(n)] = "None"
       
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')  #Clicking on next button

        next_button.click()

    except:

        break
print(len(name))                                # Printing the length of the  Extracted Data
print(len(distance))
print(len(ratings))
print(len(reviews))
print(len(treview))
print(len(private))
print(len(dorms))
print(len(facilities))
print(len(hurl))
# Out:
# 60
# 60
# 60
# 60
# 60
# 120
# 120
# 60
# 60

# %% [markdown]
# Here "Privates from Price" and "Dorms from Price" were under the same class so there data were coming together, so just used range function and extracted the desired data that we want

# %%
p=private[0:200:2]
pp=dorms[1:200:2]
print(len(p))
print(len(pp))
# Out:
# 60
# 60

# %%
# Extracting the Description of each hotels by individually going to each url of each hosel as we have already extracted the url of each Hostel's

description = []
for i in hurl:    
    try:
        driver.get(i)
        try:
            see=driver.find_element_by_xpath('//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[2]/div/div/a')
            see.click()
        except:
            pass   
        time.sleep(1)
        des=driver.find_element_by_xpath('//div[@class="description-container"]')
        description.append(des.text)
    
    except NoSuchElementException:
        description.append("No Description Availabe")

# %%
len(description)
# Out:
# 60

# %%
# Now Creating DataFrame:
df9 = pd.DataFrame({'Hostel Name':name,'Distance From City Centre':distance,'Total Reviews':treview,'Overall Reviews':reviews,'Privates From Price':p,'Dorms From Price':pp,'Facilities':facilities,'Property Description':description})
df9
# Out:
#                                 Hostel Name  \
# 0                  St Christopher's Village
# 1             Palmers Lodge - Swiss Cottage
# 2               Wombat's City Hostel London
# 3                          Generator London
# 4                          Astor Museum Inn
# 5                      Urbany Hostel London
# 6                           Astor Hyde Park
# 7         Safestay London Elephant & Castle
# 8                   Smart Camden Inn Hostel
# 9                             Pickwick Hall
# 10             No.8 Willesden Hostel London
# 11              Smart Russell Square Hostel
# 12                       No.8 Seven Sisters
# 13                       London Backpackers
# 14                 Barmy Badger Backpackers
# 15  Safestay London Kensington Holland Park
# 16                  Prime Backpackers Angel
# 17     St Christopher's Inn - London Bridge
# 18                           Phoenix Hostel
# 19              Smart Hyde Park View Hostel
# 20                  Queen Elizabeth Chelsea
# 21               Smart Hyde Park Inn Hostel
# 22                         NX London Hostel
# 23                  Hostel One Notting Hill
# 24                    YHA London St Pancras
# 25             St Christopher's Hammersmith
# 26                       Strand Continental
# 27                  St Christopher's Camden
# 28  St Christopher's Inn - Liverpool Street
# 29                   London Waterloo Hostel
# 30      PubLove @ The White Ferry, Victoria
# 31                                 Clink261
# 32               St Christopher's Greenwich
# 33     PubLove @ The Steam Engine, Waterloo
# 34          St Christopher's Shepherds Bush
# 35                    The Dictionary Hostel
# 36                         Astor Kensington
# 37             International Students House
# 38                           Astor Victoria
# 39                            Selina Camden
# 40       PubLove @ The Exmouth Arms, Euston
# 41           PubLove @ The Crown, Battersea
# 42                               Park Villa
# 43                  Saint James Backpackers
# 44                 Kensal Green Backpackers
# 45      PubLove @ The Green Man, Paddington
# 46                       Book a Bed Hostels
# 47                      Britannia Inn Hotel
# 48                              Barry House
# 49                       London House Hotel
# 50                            Elmwood Hotel
# 51                                Kip Hotel
# 52                      The W14 Hotel & Bar
# 53                          Cranbrook Hotel
# 54                           Colliers Hotel
# 55                          Belgravia Hotel
# 56                 Budget London Apartments
# 57                             Victor Hotel
# 58                    Belgrave Hotel London
# 59                    Hyde Park Court Hotel
#
#                      Distance From City Centre Total Reviews Overall Reviews  \
# 0              Hostel - 1.8km from city centre         11234        Fabulous
# 1              Hostel - 6.5km from city centre         15360          Superb
# 2              Hostel - 3.6km from city centre         13630          Superb
# 3                Hostel - 3km from city centre          Good       Very Good
# 4              Hostel - 2.2km from city centre          8947        Fabulous
# 5              Hostel - 5.4km from city centre           317          Superb
# 6              Hostel - 4.3km from city centre         11502        Fabulous
# 7              Hostel - 1.7km from city centre          Good       Very Good
# 8              Hostel - 4.4km from city centre          2848        Fabulous
# 9              Hostel - 2.3km from city centre          2345          Superb
# 10              Hostel - 10km from city centre          4747            Good
# 11             Hostel - 2.6km from city centre          Good       Very Good
# 12               Hostel - 9km from city centre          3771            Good
# 13            Hostel - 11.9km from city centre          4246        Fabulous
# 14             Hostel - 5.5km from city centre          1743          Superb
# 15             Hostel - 5.9km from city centre          1204            Good
# 16             Hostel - 3.6km from city centre           582        Fabulous
# 17             Hostel - 1.8km from city centre          3297        Fabulous
# 18             Hostel - 4.2km from city centre          3569        Fabulous
# 19               Hostel - 5km from city centre          4550        Fabulous
# 20             Hostel - 5.7km from city centre          3273            Good
# 21               Hostel - 5km from city centre          6301            Good
# 22             Hostel - 6.1km from city centre          Good       Very Good
# 23             Hostel - 5.5km from city centre          1362        Fabulous
# 24             Hostel - 3.3km from city centre          2830          Superb
# 25             Hostel - 7.5km from city centre          Good       Very Good
# 26             Hostel - 1.3km from city centre           844            Good
# 27             Hostel - 4.3km from city centre          3769        Fabulous
# 28             Hostel - 3.2km from city centre           404        Fabulous
# 29             Hostel - 0.7km from city centre          2497            Good
# 30             Hostel - 2.4km from city centre           243        Fabulous
# 31             Hostel - 3.2km from city centre            81        Fabulous
# 32             Hostel - 7.6km from city centre          Good       Very Good
# 33             Hostel - 0.5km from city centre           269        Fabulous
# 34               Hostel - 7km from city centre           667            Good
# 35             Hostel - 4.1km from city centre            50            Good
# 36             Hostel - 4.9km from city centre          6359        Fabulous
# 37             Hostel - 3.3km from city centre           945          Superb
# 38             Hostel - 1.8km from city centre         14737        Fabulous
# 39             Hostel - 5.5km from city centre            25          Superb
# 40             Hostel - 3.4km from city centre          Good       Very Good
# 41             Hostel - 4.7km from city centre          Good       Very Good
# 42             Hostel - 6.3km from city centre           865        Fabulous
# 43             Hostel - 5.5km from city centre          1792            Good
# 44             Hostel - 8.2km from city centre          3620            None
# 45             Hostel - 4.3km from city centre          Good       Very Good
# 46             Hostel - 6.9km from city centre          1183            Good
# 47             Hotel - 14.5km from city centre            19        Fabulous
# 48  Bed and Breakfast - 4.2km from city centre            11        Fabulous
# 49              Hotel - 5.3km from city centre          1381        Fabulous
# 50              Hotel - 3.2km from city centre          Good       Very Good
# 51              Hotel - 6.8km from city centre            53        Fabulous
# 52              Hotel - 6.5km from city centre           278          Superb
# 53             Hotel - 14.8km from city centre            58            None
# 54              Hotel - 2.1km from city centre          Good       Very Good
# 55              Hotel - 2.4km from city centre             8        Fabulous
# 56          Apartment - 8.2km from city centre           356            None
# 57              Hotel - 1.8km from city centre             2            None
# 58              Hotel - 2.2km from city centre             6            None
# 59              Hotel - 4.3km from city centre           138            None
#
#                 Privates From Price            Dorms From Price  \
# 0     Privates FromRs6267.51 Rs5641  Dorms FromRs1610.69 Rs1450
# 1             No Privates Available            Dorms FromRs1932
# 2   Privates FromRs14057.21 Rs10543  Dorms FromRs3307.48 Rs2481
# 3               Privates FromRs7089            Dorms FromRs2362
# 4             No Privates Available            Dorms FromRs2434
# 5              Privates FromRs12722            Dorms FromRs2650
# 6             No Privates Available            Dorms FromRs1980
# 7               Privates FromRs8178            Dorms FromRs1606
# 8             No Privates Available            Dorms FromRs1554
# 9               Privates FromRs8762          No Dorms Available
# 10              Privates FromRs3013            Dorms FromRs1228
# 11             Privates FromRs12311            Dorms FromRs1344
# 12            No Privates Available            Dorms FromRs1131
# 13              Privates FromRs5913            Dorms FromRs1519
# 14            No Privates Available            Dorms FromRs2726
# 15              Privates FromRs6279            Dorms FromRs1490
# 16            No Privates Available            Dorms FromRs2215
# 17            No Privates Available  Dorms FromRs1898.42 Rs1709
# 18            No Privates Available  Dorms FromRs1687.49 Rs1519
# 19             Privates FromRs10166            Dorms FromRs1335
# 20              Privates FromRs4860            Dorms FromRs1696
# 21            No Privates Available            Dorms FromRs1238
# 22    Privates FromRs4993.74 Rs4245  Dorms FromRs1665.28 Rs1582
# 23             Privates FromRs16485            Dorms FromRs2632
# 24             Privates FromRs18464          No Dorms Available
# 25            No Privates Available  Dorms FromRs1502.51 Rs1352
# 26            No Privates Available            Dorms FromRs2629
# 27            No Privates Available  Dorms FromRs1610.69 Rs1450
# 28            No Privates Available  Dorms FromRs2006.23 Rs1806
# 29            No Privates Available            Dorms FromRs2313
# 30            No Privates Available            Dorms FromRs2596
# 31            No Privates Available  Dorms FromRs1820.54 Rs1638
# 32            No Privates Available  Dorms FromRs1502.51 Rs1352
# 33            No Privates Available            Dorms FromRs3180
# 34            No Privates Available  Dorms FromRs1567.42 Rs1411
# 35            No Privates Available  Dorms FromRs1999.02 Rs1799
# 36            No Privates Available            Dorms FromRs2044
# 37              Privates FromRs5890          No Dorms Available
# 38            No Privates Available            Dorms FromRs1850
# 39  Privates FromRs20405.64 Rs17345  Dorms FromRs7652.12 Rs6504
# 40            No Privates Available            Dorms FromRs1850
# 41            No Privates Available            Dorms FromRs2174
# 42            No Privates Available            Dorms FromRs4712
# 43    Privates FromRs6829.89 Rs6488  Dorms FromRs2531.23 Rs2405
# 44            No Privates Available            Dorms FromRs1558
# 45            No Privates Available            Dorms FromRs1752
# 46    Privates FromRs7506.44 Rs6756  Dorms FromRs1969.46 Rs1773
# 47              Privates FromRs5841          No Dorms Available
# 48              Privates FromRs5387          No Dorms Available
# 49  Privates FromRs18604.57 Rs13023          No Dorms Available
# 50              Privates FromRs8275          No Dorms Available
# 51              Privates FromRs8437          No Dorms Available
# 52             Privates FromRs15026          No Dorms Available
# 53              Privates FromRs5744          No Dorms Available
# 54              Privates FromRs7172          No Dorms Available
# 55              Privates FromRs6046          No Dorms Available
# 56              Privates FromRs6101          No Dorms Available
# 57             Privates FromRs13500          No Dorms Available
# 58              Privates FromRs7529          No Dorms Available
# 59              Privates FromRs9573          No Dorms Available
#
#                                            Facilities  \
# 0     Free WiFi\nFollows Covid-19 sanitation guidance
# 1     Free WiFi\nFollows Covid-19 sanitation guidance
# 2     Free WiFi\nFollows Covid-19 sanitation guidance
# 3     Free WiFi\nFollows Covid-19 sanitation guidance
# 4     Free WiFi\nFollows Covid-19 sanitation guidance
# 5     Free WiFi\nFollows Covid-19 sanitation guidance
# 6     Free WiFi\nFollows Covid-19 sanitation guidance
# 7     Free WiFi\nFollows Covid-19 sanitation guidance
# 8     Free WiFi\nFollows Covid-19 sanitation guidance
# 9                                      Free Breakfast
# 10    Free WiFi\nFollows Covid-19 sanitation guidance
# 11    Free WiFi\nFollows Covid-19 sanitation guidance
# 12    Free WiFi\nFollows Covid-19 sanitation guidance
# 13  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 14                          Free WiFi\nFree Breakfast
# 15                                          Free WiFi
# 16    Free WiFi\nFollows Covid-19 sanitation guidance
# 17    Free WiFi\nFollows Covid-19 sanitation guidance
# 18    Free WiFi\nFollows Covid-19 sanitation guidance
# 19    Free WiFi\nFollows Covid-19 sanitation guidance
# 20                                          Free WiFi
# 21                                          Free WiFi
# 22                          Free WiFi\nFree Breakfast
# 23                                          Free WiFi
# 24    Free WiFi\nFollows Covid-19 sanitation guidance
# 25    Free WiFi\nFollows Covid-19 sanitation guidance
# 26               Follows Covid-19 sanitation guidance
# 27    Free WiFi\nFollows Covid-19 sanitation guidance
# 28    Free WiFi\nFollows Covid-19 sanitation guidance
# 29    Free WiFi\nFollows Covid-19 sanitation guidance
# 30    Free WiFi\nFollows Covid-19 sanitation guidance
# 31    Free WiFi\nFollows Covid-19 sanitation guidance
# 32    Free WiFi\nFollows Covid-19 sanitation guidance
# 33    Free WiFi\nFollows Covid-19 sanitation guidance
# 34    Free WiFi\nFollows Covid-19 sanitation guidance
# 35                                          Free WiFi
# 36    Free WiFi\nFollows Covid-19 sanitation guidance
# 37    Free WiFi\nFollows Covid-19 sanitation guidance
# 38    Free WiFi\nFollows Covid-19 sanitation guidance
# 39                                          Free WiFi
# 40    Free WiFi\nFollows Covid-19 sanitation guidance
# 41    Free WiFi\nFollows Covid-19 sanitation guidance
# 42    Free WiFi\nFollows Covid-19 sanitation guidance
# 43  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 44               Follows Covid-19 sanitation guidance
# 45    Free WiFi\nFollows Covid-19 sanitation guidance
# 46                                          Free WiFi
# 47  Free Breakfast\nFollows Covid-19 sanitation gu...
# 48                          Free WiFi\nFree Breakfast
# 49                                          Free WiFi
# 50
# 51                                          Free WiFi
# 52                          Free WiFi\nFree Breakfast
# 53  Free Breakfast\nFollows Covid-19 sanitation gu...
# 54               Follows Covid-19 sanitation guidance
# 55                                          Free WiFi
# 56                                          Free WiFi
# 57                                          Free WiFi
# 58                          Free WiFi\nFree Breakfast
# 59                          Free WiFi\nFree Breakfast
#
#                                  Property Description
# 0   Hostelworld says\nHostelworld visitors have sa...
# 1   Hostelworld says\nPalmers Lodge - Swiss Cottag...
# 2   Property Description\nA safe haven in the midd...
# 3   Hostelworld says\nHostelworld guests have said...
# 4   Hostelworld says\nNote: 18-40 yrs old only. As...
# 5   Property Description\nWelcome to Urbany Hostel...
# 6   Hostelworld says\nNote: 18-40 yrs old only. As...
# 7   Hostelworld says\nSafestay at Elephant and Cas...
# 8   Property Description\nLocated in the middle of...
# 9   Property Description\nPickwick Hall provides a...
# 10  Property Description\nAt No.8 we take pride in...
# 11  Hostelworld says\nMany Hostelworld guests who ...
# 12  Property Description\nFor Great Facilities, Co...
# 13  Property Description\nIMPORTANT NOTICE: This h...
# 14  Property Description\nThe Badger is unique for...
# 15  Property Description\nSafestay Holland Park\n\...
# 16  Property Description\nThe hostel is housed in ...
# 17  Hostelworld says\nSt Christopher's Inn - Londo...
# 18  Property Description\n*Please note we are oper...
# 19  Hostelworld says\nSmart Hyde Park View is a 'c...
# 20  Property Description\nPLEASE NOTE WE ONLY ACCE...
# 21  Property Description\nSmart Hyde Park Inn Host...
# 22  Property Description\nWelcome to NX London Hos...
# 23  Property Description\nThe perfect place for so...
# 24  Hostelworld says\nYHA London St Pancras has fr...
# 25  Hostelworld says\nThe friendly, attentive and ...
# 26  Property Description\nWelcome to one of London...
# 27  Hostelworld says\nIf you're looking to explore...
# 28  Property Description\nCOVID 19 Policy Update.\...
# 29  Property Description\nNote: 18-40 yrs old only...
# 30  Hostelworld says\nThe White Ferry, Bestplace I...
# 31  Hostelworld says\nClink261 is near King's Cros...
# 32  Hostelworld says\nSt Christopher's Greenwich i...
# 33  Hostelworld says\nThe Steam Engine, Bestplace ...
# 34  Hostelworld says\nSt Christopher's Shepherds B...
# 35  Property Description\nA friendly hostel situat...
# 36  Hostelworld says\nNote: 18-40 yrs old only. As...
# 37  Property Description\nInternational Students H...
# 38  Hostelworld says\nNote: 18-40 yrs old only. As...
# 39  Property Description\nAmong underground music ...
# 40  Property Description\nDo Camden by day and cur...
# 41  Property Description\nDo London like a local.\...
# 42  Property Description\nPark Villa is a new bout...
# 43  Hostelworld says\nSaint James Backpackers, set...
# 44  Property Description\nKensal Green Backpackers...
# 45  Hostelworld says\nThe Green Man Bestplace Inn ...
# 46  Property Description\nWelcome to Venture Hoste...
# 47  Property Description\nThe Britannia Inn Hotel ...
# 48  Property Description\nBarry House is a Central...
# 49  Property Description\nOur lovely boutique hote...
# 50  Property Description\nThis central London hote...
# 51  Property Description\nKip is on a mission to b...
# 52  Property Description\nThe W14 Hotel London is ...
# 53  Property Description\nWe are located about twe...
# 54  Property Description\nColliers Hotel offers ba...
# 55  Property Description\nBelgravia Hotel ia ideal...
# 56  Property Description\nWe offer the best budget...
# 57  Property Description\nThe Victor Hotel is a 3-...
# 58  Property Description\nThis bright, clean and f...
# 59  Property Description\nThe Hyde Park Court Hote...
